# %% [markdown]
# # <b>Final Project - Job Application Helper (Resume Screening / Recommending Job / Comparing Job Description and Resume)</b>

# %% [markdown]
# #### Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Importing the dataset into dataframe and displaying the first 5 rows in it.

# %%
df1 = pd.read_csv('data.csv')
df1.head()
# Out:
#                                               Resume                   Label
# 0  Database Administrator Database Administrator ...  Database_Administrator
# 1  Database Administrator Database Administrator ...  Database_Administrator
# 2  Oracle Database Administrator Oracle Database ...  Database_Administrator
# 3  Amazon Redshift Administrator and ETL Develope...  Database_Administrator
# 4  Scrum Master Scrum Master Scrum Master Richmon...  Database_Administrator

# %%
# Rename the column
df1.rename(columns={'Label': 'Category'}, inplace=True)
df1.head()
# Out:
#                                               Resume                Category
# 0  Database Administrator Database Administrator ...  Database_Administrator
# 1  Database Administrator Database Administrator ...  Database_Administrator
# 2  Oracle Database Administrator Oracle Database ...  Database_Administrator
# 3  Amazon Redshift Administrator and ETL Develope...  Database_Administrator
# 4  Scrum Master Scrum Master Scrum Master Richmon...  Database_Administrator

# %% [markdown]
# # <b>Data Exploration</b>

# %% [markdown]
# - Checking if the dataset has any null values or not

# %%
df1.isnull().sum()
# Out:
# Resume        2
# Category    748
# dtype: int64

# %%
df1.dropna(inplace=True)
df1.isnull().sum()
# Out:
# Resume      0
# Category    0
# dtype: int64

# %% [markdown]
# - Finding basic information about the dataset
#     - It has 29033 rows and 2 columns
#     - Both the columns contains data of Object datatype i.e. string

# %%
print(df1.shape)
print(df1.info())
# Out:
# (29033, 2)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29033 entries, 0 to 29782
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Resume    29033 non-null  object
#  1   Category  29033 non-null  object
# dtypes: object(2)
# memory usage: 680.5+ KB
# None

# %% [markdown]
# - Looking at the Unique Categories

# %%
unique_categories = df1['Category'].unique()
print(unique_categories)
# Out:
# ['Database_Administrator' 'Database_Administrator,Software_Developer'
#  'Systems_Administrator,Database_Administrator'
#  'Project_manager,Database_Administrator'
#  'Database_Administrator,Project_manager'
#  'Database_Administrator,Security_Analyst'
#  'Software_Developer,Database_Administrator'
#  'Web_Developer,Software_Developer,Database_Administrator'
#  'Security_Analyst,Database_Administrator'
#  'Database_Administrator,Web_Developer,Software_Developer'
#  'Database_Administrator,Systems_Administrator'
#  'Database_Administrator,Project_manager,Network_Administrator'
#  'Database_Administrator,Network_Administrator'
#  'Database_Administrator,Network_Administrator,Project_manager'
#  'Database_Administrator,Systems_Administrator,Software_Developer'
#  'Database_Administrator,Network_Administrator,Software_Developer'
#  'Software_Developer,Systems_Administrator,Security_Analyst'
#  'Systems_Administrator,Database_Administrator,Project_manager'
#  'Systems_Administrator,Software_Developer,Database_Administrator'
#  'Network_Administrator,Database_Administrator,Software_Developer'
#  'Systems_Administrator' 'Network_Administrator,Database_Administrator'
#  'Database_Administrator,Systems_Administrator,Security_Analyst'
#  'Project_manager,Database_Administrator,Software_Developer,Web_Developer,Network_Administrator'
#  'Project_manager,Systems_Administrator,Network_Administrator'
#  'Project_manager'
#  'Software_Developer,Web_Developer,Database_Administrator'
#  'Database_Administrator,Web_Developer,Software_Developer,Systems_Administrator'
#  'Software_Developer,Database_Administrator,Network_Administrator'
#  'Software_Developer,Front_End_Developer,Web_Developer,Database_Administrator,Network_Administrator'
#  'Software_Developer'
#  'Systems_Administrator,Project_manager,Database_Administrator'
#  'Java_Developer,Software_Developer,Database_Administrator'
#  'Database_Administrator,Network_Administrator,Systems_Administrator'
#  'Systems_Administrator,Network_Administrator,Database_Administrator'
#  'Software_Developer,Database_Administrator,Systems_Administrator'
#  'Database_Administrator,Systems_Administrator,Network_Administrator'
#  'Project_manager,Software_Developer,Web_Developer'
#  'Database_Administrator,Systems_Administrator,Project_manager'
#  'Project_manager,Database_Administrator,Security_Analyst,Software_Developer'
#  'Web_Developer,Software_Developer'
#  'Web_Developer,Software_Developer,Database_Administrator,Systems_Administrator'
#  'Software_Developer,Front_End_Developer,Project_manager,Database_Administrator'
#  'Network_Administrator' 'Software_Developer,Systems_Administrator'
#  'Systems_Administrator,Project_manager'
#  'Network_Administrator,Systems_Administrator,Database_Administrator'
#  'Project_manager,Network_Administrator'
#  'Systems_Administrator,Database_Administrator,Software_Developer'
#  'Security_Analyst,Database_Administrator,Software_Developer'
#  'Software_Developer,Project_manager,Database_Administrator'
#  'Network_Administrator,Database_Administrator,Systems_Administrator'
#  'Database_Administrator,Software_Developer,Systems_Administrator'
#  'Project_manager,Database_Administrator,Systems_Administrator,Software_Developer'
#  'Security_Analyst,Systems_Administrator'
#  'Web_Developer,Software_Developer,Systems_Administrator,Database_Administrator'
#  'Systems_Administrator,Network_Administrator,Project_manager'
#  'Systems_Administrator,Database_Administrator,Network_Administrator'
#  'Database_Administrator,Systems_Administrator,Software_Developer,Project_manager'
#  'Project_manager,Database_Administrator,Systems_Administrator'
#  'Database_Administrator,Web_Developer,Software_Developer,Project_manager,Systems_Administrator'
#  'Database_Administrator,Software_Developer,Network_Administrator'
#  'Software_Developer,Database_Administrator,Project_manager'
#  'Database_Administrator,Project_manager,Software_Developer'
#  'Database_Administrator,Software_Developer,Front_End_Developer'
#  'Network_Administrator,Project_manager,Web_Developer,Software_Developer,Database_Administrator,Systems_Administrator'
#  'Project_manager,Database_Administrator,Network_Administrator'
#  'Database_Administrator,Project_manager,Systems_Administrator'
#  'Systems_Administrator,Security_Analyst,Database_Administrator'
#  'Database_Administrator,Project_manager,Systems_Administrator,Software_Developer'
#  'Software_Developer,Database_Administrator,Web_Developer'
#  'Database_Administrator,Project_manager,Systems_Administrator,Network_Administrator'
#  'Project_manager,Database_Administrator,Software_Developer'
#  'Security_Analyst,Database_Administrator,Systems_Administrator'
#  'Software_Developer,Systems_Administrator,Project_manager,Java_Developer,Database_Administrator,Web_Developer'
#  'Database_Administrator,Systems_Administrator,Web_Developer,Software_Developer,Network_Administrator'
#  'Systems_Administrator,Software_Developer'
#  'Systems_Administrator,Database_Administrator,Security_Analyst'
#  'Project_manager,Database_Administrator,Network_Administrator,Systems_Administrator'
#  'Database_Administrator,Software_Developer,Project_manager'
#  'Systems_Administrator,Database_Administrator,Project_manager,Software_Developer'
#  'Software_Developer,Web_Developer,Database_Administrator,Network_Administrator'
#  'Database_Administrator,Systems_Administrator,Security_Analyst,Network_Administrator'
#  'Project_manager,Systems_Administrator,Database_Administrator'
#  'Security_Analyst,Network_Administrator,Database_Administrator,Systems_Administrator'
#  'Software_Developer,Database_Administrator,Web_Developer,Project_manager'
#  'Database_Administrator,Systems_Administrator,Java_Developer,Software_Developer'
#  'Database_Administrator,Security_Analyst,Systems_Administrator'
#  'Database_Administrator,Network_Administrator,Web_Developer,Software_Developer,Systems_Administrator'
#  'Database_Administrator,Systems_Administrator,Project_manager,Software_Developer'
#  'Project_manager,Network_Administrator,Database_Administrator'
#  'Database_Administrator,Network_Administrator,Software_Developer,Systems_Administrator,Security_Analyst'
#  'Database_Administrator,Software_Developer,Systems_Administrator,Project_manager'
#  'Database_Administrator,Project_manager,Web_Developer,Software_Developer'
#  'Software_Developer,Systems_Administrator,Network_Administrator,Database_Administrator,Project_manager'
#  'Systems_Administrator,Network_Administrator,Database_Administrator,Project_manager'
#  'Database_Administrator,Software_Developer,Web_Developer'
#  'Project_manager,Systems_Administrator'
#  'Software_Developer,Web_Developer,Database_Administrator,Project_manager'
#  'Software_Developer,Web_Developer,Front_End_Developer,Database_Administrator'
#  'Systems_Administrator,Database_Administrator,Web_Developer,Software_Developer,Project_manager'
#  'Systems_Administrator,Database_Administrator,Project_manager,Network_Administrator'
#  'Systems_Administrator,Network_Administrator,Security_Analyst'
#  'Project_manager,Software_Developer'
#  'Systems_Administrator,Web_Developer,Software_Developer,Network_Administrator'
#  'Project_manager,Database_Administrator,Web_Developer,Software_Developer'
#  'Network_Administrator,Database_Administrator,Project_manager'
#  'Systems_Administrator,Database_Administrator,Web_Developer,Software_Developer'
#  'Project_manager,Systems_Administrator,Database_Administrator,Network_Administrator'
#  'Security_Analyst,Database_Administrator,Network_Administrator'
#  'Database_Administrator,Web_Developer,Software_Developer,Java_Developer'
#  'Software_Developer,Front_End_Developer'
#  'Web_Developer,Software_Developer,Front_End_Developer'
#  'Web_Developer,Software_Developer,Front_End_Developer,Systems_Administrator,Project_manager'
#  'Software_Developer,Front_End_Developer,Web_Developer'
#  'Software_Developer,Front_End_Developer,Java_Developer,Web_Developer'
#  'Web_Developer,Software_Developer,Front_End_Developer,Project_manager'
#  'Software_Developer,Front_End_Developer,Java_Developer'
#  'Web_Developer,Software_Developer,Front_End_Developer,Java_Developer'
#  'Java_Developer,Software_Developer,Web_Developer,Front_End_Developer'
#  'Java_Developer,Software_Developer,Front_End_Developer'
#  'Java_Developer,Web_Developer,Software_Developer,Front_End_Developer'
#  'Web_Developer,Software_Developer,Python_Developer,Front_End_Developer'
#  'Software_Developer,Front_End_Developer,Web_Developer,Java_Developer'
#  'Software_Developer,Web_Developer,Front_End_Developer'
#  'Software_Developer,Front_End_Developer,Network_Administrator'
#  'Software_Developer,Front_End_Developer,Python_Developer'
#  'Software_Developer,Front_End_Developer,Web_Developer,Python_Developer'
#  'Systems_Administrator,Software_Developer,Front_End_Developer'
#  'Python_Developer,Software_Developer,Front_End_Developer,Web_Developer'
#  'Software_Developer,Web_Developer'
#  'Software_Developer,Front_End_Developer,Project_manager'
#  'Systems_Administrator,Java_Developer,Software_Developer,Web_Developer'
#  'Security_Analyst,Software_Developer,Front_End_Developer,Project_manager'
#  'Project_manager,Software_Developer,Web_Developer,Front_End_Developer'
#  'Software_Developer,Systems_Administrator,Web_Developer'
#  'Project_manager,Software_Developer,Front_End_Developer'
#  'Software_Developer,Project_manager,Front_End_Developer'
#  'Web_Developer,Software_Developer,Front_End_Developer,Network_Administrator'
#  'Web_Developer,Software_Developer,Front_End_Developer,Database_Administrator'
#  'Web_Developer,Software_Developer,Front_End_Developer,Systems_Administrator'
#  'Software_Developer,Front_End_Developer,Database_Administrator,Web_Developer,Project_manager'
#  'Project_manager,Web_Developer,Software_Developer,Front_End_Developer'
#  'Security_Analyst,Web_Developer,Software_Developer,Front_End_Developer'
#  'Web_Developer,Software_Developer,Systems_Administrator,Front_End_Developer'
#  'Software_Developer,Front_End_Developer,Systems_Administrator'
#  'Web_Developer,Software_Developer,Project_manager,Front_End_Developer'
#  'Security_Analyst,Software_Developer,Front_End_Developer'
#  'Software_Developer,Front_End_Developer,Network_Administrator,Security_Analyst'
#  'Network_Administrator,Systems_Administrator'
#  'Systems_Administrator,Software_Developer,Front_End_Developer,Web_Developer'
#  'Security_Analyst,Web_Developer,Software_Developer,Front_End_Developer,Systems_Administrator'
#  'Python_Developer,Software_Developer,Front_End_Developer'
#  'Python_Developer,Software_Developer,Web_Developer,Front_End_Developer'
#  'Software_Developer,Front_End_Developer,Database_Administrator'
#  'Software_Developer,Front_End_Developer,Project_manager,Web_Developer'
#  'Java_Developer,Software_Developer,Front_End_Developer,Web_Developer'
#  'Software_Developer,Front_End_Developer,Web_Developer,Systems_Administrator'
#  'Project_manager,Database_Administrator,Software_Developer,Front_End_Developer'
#  'Network_Administrator,Software_Developer,Front_End_Developer'
#  'Systems_Administrator,Web_Developer,Software_Developer,Front_End_Developer'
#  'Software_Developer,Web_Developer,Project_manager,Front_End_Developer'
#  'Software_Developer,Front_End_Developer,Systems_Administrator,Network_Administrator'
#  'Web_Developer,Software_Developer,Front_End_Developer,Project_manager,Network_Administrator'
#  'Web_Developer,Software_Developer,Project_manager'
#  'Software_Developer,Systems_Administrator,Front_End_Developer'
#  'Project_manager,Web_Developer,Software_Developer'
#  'Software_Developer,Web_Developer,Java_Developer'
#  'Software_Developer,Front_End_Developer,Web_Developer,Project_manager'
#  'Security_Analyst,Project_manager,Software_Developer,Front_End_Developer,Network_Administrator'
#  'Systems_Administrator,Software_Developer,Front_End_Developer,Project_manager,Web_Developer'
#  'Java_Developer,Software_Developer,Front_End_Developer,Project_manager'
#  'Web_Developer,Software_Developer,Front_End_Developer,Java_Developer,Database_Administrator'
#  'Software_Developer,Web_Developer,Project_manager,Front_End_Developer,Systems_Administrator'
#  'Database_Administrator,Project_manager,Software_Developer,Front_End_Developer,Java_Developer'
#  'Software_Developer,Web_Developer,Front_End_Developer,Project_manager'
#  'Project_manager,Software_Developer,Database_Administrator'
#  'Database_Administrator,Web_Developer,Software_Developer,Front_End_Developer,Systems_Administrator'
#  'Software_Developer,Front_End_Developer,Project_manager,Java_Developer'
#  'Software_Developer,Web_Developer,Front_End_Developer,Systems_Administrator'
#  'Web_Developer,Software_Developer,Front_End_Developer,Database_Administrator,Network_Administrator'
#  'Systems_Administrator,Network_Administrator'
#  'Web_Developer,Software_Developer,Project_manager,Network_Administrator,Front_End_Developer'
#  'Software_Developer,Front_End_Developer,Java_Developer,Database_Administrator'
#  'Project_manager,Software_Developer,Front_End_Developer,Web_Developer'
#  'Web_Developer,Software_Developer,Front_End_Developer,Java_Developer,Project_manager'
#  'Software_Developer,Java_Developer,Web_Developer,Front_End_Developer'
#  'Security_Analyst,Software_Developer,Front_End_Developer,Network_Administrator'
#  'Software_Developer,Front_End_Developer,Java_Developer,Web_Developer,Project_manager'
#  'Software_Developer,Project_manager,Front_End_Developer,Web_Developer'
#  'Security_Analyst,Software_Developer,Network_Administrator,Front_End_Developer'
#  'Web_Developer,Software_Developer,Front_End_Developer,Python_Developer'
#  'Java_Developer,Software_Developer'
#  'Project_manager,Web_Developer,Software_Developer,Systems_Administrator,Front_End_Developer'
#  'Software_Developer,Web_Developer,Project_manager'
#  'Project_manager,Security_Analyst'
#  'Project_manager,Systems_Administrator,Software_Developer'
#  'Software_Developer,Project_manager'
#  'Systems_Administrator,Project_manager,Network_Administrator'
#  'Project_manager,Software_Developer,Web_Developer,Python_Developer'
#  'Security_Analyst'
#  'Network_Administrator,Security_Analyst,Project_manager'
#  'Project_manager,Network_Administrator,Software_Developer'
#  'Network_Administrator,Project_manager,Security_Analyst,Systems_Administrator'
#  'Network_Administrator,Project_manager'
#  'Project_manager,Security_Analyst,Software_Developer'
#  'Security_Analyst,Project_manager'
#  'Project_manager,Network_Administrator,Systems_Administrator'
#  'Security_Analyst,Project_manager,Network_Administrator,Systems_Administrator'
#  'Systems_Administrator,Software_Developer,Project_manager'
#  'Web_Developer,Software_Developer,Systems_Administrator,Project_manager'
#  'Systems_Administrator,Network_Administrator,Security_Analyst,Project_manager'
#  'Project_manager,Security_Analyst,Network_Administrator'
#  'Systems_Administrator,Project_manager,Web_Developer,Software_Developer'
#  'Software_Developer,Project_manager,Systems_Administrator,Web_Developer'
#  'Project_manager,Software_Developer,Network_Administrator'
#  'Project_manager,Software_Developer,Systems_Administrator'
#  'Project_manager,Security_Analyst,Network_Administrator,Software_Developer'
#  'Project_manager,Security_Analyst,Systems_Administrator'
#  'Project_manager,Software_Developer,Java_Developer'
#  'Project_manager,Security_Analyst,Web_Developer,Software_Developer'
#  'Software_Developer,Project_manager,Web_Developer'
#  'Project_manager,Network_Administrator,Security_Analyst'
#  'Java_Developer,Software_Developer,Project_manager'
#  'Network_Administrator,Security_Analyst,Systems_Administrator,Project_manager'
#  'Software_Developer,Project_manager,Network_Administrator'
#  'Security_Analyst,Project_manager,Systems_Administrator'
#  'Project_manager,Java_Developer,Software_Developer,Network_Administrator'
#  'Software_Developer,Project_manager,Systems_Administrator'
#  'Project_manager,Software_Developer,Systems_Administrator,Network_Administrator'
#  'Network_Administrator,Project_manager,Systems_Administrator'
#  'Project_manager,Security_Analyst,Systems_Administrator,Network_Administrator'
#  'Project_manager,Software_Developer,Systems_Administrator,Web_Developer'
#  'Software_Developer,Network_Administrator,Project_manager'
#  'Project_manager,Java_Developer,Software_Developer'
#  'Project_manager,Web_Developer,Software_Developer,Systems_Administrator'
#  'Security_Analyst,Software_Developer'
#  'Systems_Administrator,Security_Analyst'
#  'Security_Analyst,Network_Administrator,Systems_Administrator'
#  'Security_Analyst,Network_Administrator'
#  'Network_Administrator,Security_Analyst'
#  'Security_Analyst,Systems_Administrator,Project_manager'
#  'Software_Developer,Security_Analyst'
#  'Project_manager,Security_Analyst,Software_Developer,Systems_Administrator'
#  'Security_Analyst,Systems_Administrator,Network_Administrator'
#  'Systems_Administrator,Project_manager,Security_Analyst'
#  'Systems_Administrator,Security_Analyst,Project_manager'
#  'Network_Administrator,Systems_Administrator,Security_Analyst'
#  'Security_Analyst,Python_Developer,Software_Developer,Systems_Administrator'
#  'Web_Developer,Software_Developer,Systems_Administrator'
#  'Systems_Administrator,Software_Developer,Security_Analyst'
#  'Security_Analyst,Software_Developer,Web_Developer'
#  'Network_Administrator,Security_Analyst,Systems_Administrator'
#  'Security_Analyst,Web_Developer,Software_Developer,Systems_Administrator'
#  'Security_Analyst,Project_manager,Software_Developer'
#  'Database_Administrator,Web_Developer,Software_Developer,Network_Administrator'
#  'Security_Analyst,Java_Developer,Software_Developer'
#  'Security_Analyst,Web_Developer,Software_Developer'
#  'Security_Analyst,Network_Administrator,Project_manager,Systems_Administrator'
#  'Security_Analyst,Network_Administrator,Software_Developer'
#  'Security_Analyst,Project_manager,Network_Administrator'
#  'Security_Analyst,Systems_Administrator,Software_Developer'
#  'Security_Analyst,Network_Administrator,Project_manager'
#  'Systems_Administrator,Project_manager,Network_Administrator,Security_Analyst'
#  'Systems_Administrator,Security_Analyst,Network_Administrator,Project_manager'
#  'Software_Developer,Security_Analyst,Project_manager'
#  'Security_Analyst,Project_manager,Web_Developer,Software_Developer'
#  'Database_Administrator,Software_Developer,Security_Analyst'
#  'Network_Administrator,Systems_Administrator,Project_manager,Security_Analyst'
#  'Network_Administrator,Systems_Administrator,Security_Analyst,Project_manager'
#  'Project_manager,Security_Analyst,Network_Administrator,Systems_Administrator'
#  'Java_Developer,Software_Developer,Security_Analyst'
#  'Systems_Administrator,Security_Analyst,Network_Administrator'
#  'Systems_Administrator,Security_Analyst,Project_manager,Network_Administrator'
#  'Software_Developer,Systems_Administrator,Project_manager'
#  'Project_manager,Security_Analyst,Network_Administrator,Database_Administrator'
#  'Software_Developer,Network_Administrator,Systems_Administrator'
#  'Security_Analyst,Project_manager,Systems_Administrator,Network_Administrator'
#  'Project_manager,Systems_Administrator,Security_Analyst,Java_Developer,Web_Developer,Software_Developer'
#  'Network_Administrator,Security_Analyst,Systems_Administrator,Project_manager,Software_Developer'
#  'Security_Analyst,Systems_Administrator,Project_manager,Network_Administrator'
#  'Systems_Administrator,Database_Administrator,Security_Analyst,Network_Administrator,Project_manager'
#  'Network_Administrator,Software_Developer,Project_manager,Security_Analyst'
#  'Project_manager,Systems_Administrator,Network_Administrator,Security_Analyst'
#  'Security_Analyst,Software_Developer,Project_manager'
#  'Systems_Administrator,Project_manager,Security_Analyst,Software_Developer,Database_Administrator'
#  'Web_Developer,Software_Developer,Systems_Administrator,Security_Analyst,Network_Administrator'
#  'Network_Administrator,Security_Analyst,Database_Administrator,Project_manager'
#  'Security_Analyst,Software_Developer,Systems_Administrator,Project_manager'
#  'Project_manager,Network_Administrator,Systems_Administrator,Security_Analyst'
#  'Network_Administrator,Project_manager,Security_Analyst'
#  'Security_Analyst,Systems_Administrator,Network_Administrator,Project_manager'
#  'Security_Analyst,Software_Developer,Systems_Administrator'
#  'Project_manager,Network_Administrator,Software_Developer,Systems_Administrator'
#  'Systems_Administrator,Security_Analyst,Software_Developer'
#  'Network_Administrator,Security_Analyst,Software_Developer'
#  'Project_manager,Security_Analyst,Software_Developer,Database_Administrator,Systems_Administrator,Network_Administrator'
#  'Project_manager,Security_Analyst,Database_Administrator,Software_Developer'
#  'Project_manager,Security_Analyst,Database_Administrator'
#  'Security_Analyst,Project_manager,Database_Administrator'
#  'Security_Analyst,Systems_Administrator,Network_Administrator,Web_Developer,Software_Developer'
#  'Software_Developer,Security_Analyst,Systems_Administrator'
#  'Security_Analyst,Web_Developer,Software_Developer,Project_manager,Systems_Administrator'
#  'Security_Analyst,Software_Developer,Systems_Administrator,Network_Administrator'
#  'Systems_Administrator,Network_Administrator,Security_Analyst,Software_Developer'
#  'Project_manager,Security_Analyst,Database_Administrator,Network_Administrator'
#  'Project_manager,Systems_Administrator,Security_Analyst'
#  'Project_manager,Systems_Administrator,Network_Administrator,Software_Developer,Security_Analyst'
#  'Software_Developer,Systems_Administrator,Project_manager,Web_Developer,Network_Administrator'
#  'Project_manager,Security_Analyst,Software_Developer,Network_Administrator'
#  'Systems_Administrator,Security_Analyst,Project_manager,Web_Developer,Software_Developer'
#  'Security_Analyst,Network_Administrator,Software_Developer,Systems_Administrator'
#  'Network_Administrator,Systems_Administrator,Project_manager'
#  'Security_Analyst,Software_Developer,Network_Administrator'
#  'Network_Administrator,Web_Developer,Software_Developer,Systems_Administrator,Security_Analyst'
#  'Security_Analyst,Systems_Administrator,Project_manager,Software_Developer'
#  'Network_Administrator,Security_Analyst,Project_manager,Systems_Administrator'
#  'Security_Analyst,Web_Developer,Software_Developer,Project_manager'
#  'Software_Developer,Project_manager,Security_Analyst'
#  'Systems_Administrator,Project_manager,Security_Analyst,Network_Administrator'
#  'Java_Developer,Web_Developer,Software_Developer'
#  'Java_Developer,Software_Developer,Web_Developer'
#  'Project_manager,Java_Developer,Web_Developer,Software_Developer'
#  'Software_Developer,Java_Developer'
#  'Software_Developer,Java_Developer,Web_Developer'
#  'Web_Developer,Software_Developer,Java_Developer'
#  'Software_Developer,Database_Administrator,Java_Developer,Web_Developer'
#  'Java_Developer,Software_Developer,Systems_Administrator'
#  'Python_Developer,Software_Developer,Java_Developer'
#  'Java_Developer,Web_Developer,Software_Developer,Systems_Administrator'
#  'Python_Developer,Software_Developer,Java_Developer,Web_Developer'
#  'Java_Developer,Software_Developer,Systems_Administrator,Network_Administrator'
#  'Python_Developer,Software_Developer,Java_Developer,Front_End_Developer'
#  'Systems_Administrator,Java_Developer,Software_Developer'
#  'Java_Developer,Software_Developer,Network_Administrator'
#  'Software_Developer,Java_Developer,Systems_Administrator'
#  'Java_Developer,Python_Developer,Software_Developer'
#  'Web_Developer,Python_Developer,Software_Developer,Java_Developer'
#  'Java_Developer,Software_Developer,Web_Developer,Systems_Administrator'
#  'Java_Developer,Software_Developer,Web_Developer,Project_manager'
#  'Python_Developer,Software_Developer,Web_Developer,Java_Developer'
#  'Database_Administrator,Java_Developer,Software_Developer,Web_Developer'
#  'Software_Developer,Systems_Administrator,Java_Developer'
#  'Systems_Administrator,Java_Developer,Software_Developer,Network_Administrator'
#  'Systems_Administrator,Software_Developer,Java_Developer'
#  'Software_Developer,Java_Developer,Front_End_Developer'
#  'Java_Developer,Software_Developer,Systems_Administrator,Front_End_Developer'
#  'Database_Administrator,Java_Developer,Software_Developer,Project_manager'
#  'Software_Developer,Project_manager,Java_Developer'
#  'Database_Administrator,Java_Developer,Software_Developer,Systems_Administrator,Web_Developer'
#  'Web_Developer,Software_Developer,Java_Developer,Systems_Administrator'
#  'Project_manager,Java_Developer,Software_Developer,Web_Developer'
#  'Software_Developer,Java_Developer,Project_manager'
#  'Database_Administrator,Java_Developer,Software_Developer'
#  'Database_Administrator,Java_Developer,Python_Developer,Software_Developer'
#  'Database_Administrator,Java_Developer,Web_Developer,Software_Developer'
#  'Java_Developer,Software_Developer,Python_Developer'
#  'Web_Developer,Software_Developer,Java_Developer,Front_End_Developer'
#  'Java_Developer,Web_Developer,Software_Developer,Database_Administrator,Network_Administrator'
#  'Java_Developer,Software_Developer,Front_End_Developer,Systems_Administrator,Web_Developer'
#  'Systems_Administrator,Network_Administrator,Java_Developer,Software_Developer'
#  'Network_Administrator,Software_Developer'
#  'Network_Administrator,Web_Developer,Software_Developer'
#  'Software_Developer,Systems_Administrator,Network_Administrator'
#  'Systems_Administrator,Network_Administrator,Software_Developer'
#  'Network_Administrator,Software_Developer,Systems_Administrator'
#  'Software_Developer,Network_Administrator'
#  'Systems_Administrator,Network_Administrator,Web_Developer,Software_Developer'
#  'Web_Developer,Software_Developer,Network_Administrator'
#  'Systems_Administrator,Project_manager,Network_Administrator,Software_Developer'
#  'Web_Developer,Python_Developer,Software_Developer,Network_Administrator'
#  'Systems_Administrator,Network_Administrator,Project_manager,Security_Analyst'
#  'Network_Administrator,Software_Developer,Project_manager'
#  'Project_manager,Network_Administrator,Web_Developer,Software_Developer'
#  'Network_Administrator,Project_manager,Software_Developer'
#  'Network_Administrator,Java_Developer,Software_Developer'
#  'Network_Administrator,Web_Developer,Software_Developer,Project_manager'
#  'Project_manager,Network_Administrator,Systems_Administrator,Software_Developer'
#  'Software_Developer,Java_Developer,Systems_Administrator,Network_Administrator'
#  'Python_Developer,Software_Developer'
#  'Python_Developer,Software_Developer,Network_Administrator'
#  'Web_Developer,Python_Developer,Software_Developer'
#  'Software_Developer,Python_Developer'
#  'Python_Developer,Software_Developer,Systems_Administrator'
#  'Web_Developer,Python_Developer,Software_Developer,Database_Administrator'
#  'Web_Developer,Software_Developer,Python_Developer'
#  'Python_Developer,Software_Developer,Web_Developer'
#  'Web_Developer,Python_Developer,Software_Developer,Systems_Administrator'
#  'Python_Developer,Software_Developer,Database_Administrator'
#  'Web_Developer,Software_Developer,Python_Developer,Network_Administrator'
#  'Web_Developer,Python_Developer,Software_Developer,Front_End_Developer'
#  'Project_manager,Python_Developer,Software_Developer'
#  'Security_Analyst,Python_Developer,Software_Developer'
#  'Network_Administrator,Python_Developer,Software_Developer'
#  'Python_Developer,Software_Developer,Web_Developer,Database_Administrator'
#  'Web_Developer,Software_Developer,Systems_Administrator,Python_Developer'
#  'Database_Administrator,Python_Developer,Software_Developer'
#  'Software_Developer,Database_Administrator,Python_Developer,Web_Developer'
#  'Software_Developer,Python_Developer,Java_Developer'
#  'Software_Developer,Web_Developer,Python_Developer,Systems_Administrator'
#  'Database_Administrator,Web_Developer,Software_Developer,Python_Developer'
#  'Web_Developer,Software_Developer,Project_manager,Java_Developer'
#  'Python_Developer,Software_Developer,Java_Developer,Database_Administrator'
#  'Web_Developer,Software_Developer,Python_Developer,Database_Administrator'
#  'Database_Administrator,Web_Developer,Software_Developer,Python_Developer,Front_End_Developer'
#  'Java_Developer,Software_Developer,Web_Developer,Python_Developer'
#  'Software_Developer,Java_Developer,Python_Developer,Front_End_Developer'
#  'Software_Developer,Python_Developer,Systems_Administrator'
#  'Java_Developer,Python_Developer,Software_Developer,Project_manager'
#  'Python_Developer,Software_Developer,Project_manager'
#  'Web_Developer,Software_Developer,Python_Developer,Project_manager'
#  'Security_Analyst,Python_Developer,Software_Developer,Web_Developer,Network_Administrator'
#  'Software_Developer,Python_Developer,Web_Developer'
#  'Python_Developer,Software_Developer,Network_Administrator,Systems_Administrator,Project_manager'
#  'Software_Developer,Web_Developer,Python_Developer,Project_manager'
#  'Software_Developer,Web_Developer,Python_Developer'
#  'Software_Developer,Python_Developer,Database_Administrator,Project_manager'
#  'Software_Developer,Python_Developer,Systems_Administrator,Java_Developer'
#  'Python_Developer,Software_Developer,Systems_Administrator,Network_Administrator'
#  'Systems_Administrator,Web_Developer,Software_Developer,Python_Developer,Network_Administrator'
#  'Software_Developer,Systems_Administrator,Python_Developer'
#  'Network_Administrator,Java_Developer,Software_Developer,Web_Developer,Project_manager,Front_End_Developer'
#  'Network_Administrator,Security_Analyst,Python_Developer,Software_Developer,Systems_Administrator'
#  'Software_Developer,Java_Developer,Network_Administrator,Python_Developer'
#  'Software_Developer,Database_Administrator,Web_Developer,Python_Developer'
#  'Software_Developer,Project_manager,Python_Developer,Front_End_Developer'
#  'Web_Developer,Python_Developer,Software_Developer,Java_Developer,Network_Administrator'
#  'Web_Developer,Python_Developer,Software_Developer,Front_End_Developer,Java_Developer'
#  'Web_Developer,Software_Developer,Python_Developer,Systems_Administrator'
#  'Java_Developer,Python_Developer,Software_Developer,Web_Developer'
#  'Software_Developer,Web_Developer,Python_Developer,Database_Administrator'
#  'Python_Developer,Software_Developer,Database_Administrator,Systems_Administrator'
#  'Web_Developer,Software_Developer,Python_Developer,Java_Developer'
#  'Java_Developer,Web_Developer,Software_Developer,Python_Developer,Project_manager,Network_Administrator'
#  'Software_Developer,Python_Developer,Systems_Administrator,Java_Developer,Web_Developer'
#  'Python_Developer,Software_Developer,Database_Administrator,Web_Developer'
#  'Software_Developer,Project_manager,Java_Developer,Systems_Administrator'
#  'Software_Developer,Web_Developer,Python_Developer,Database_Administrator,Network_Administrator'
#  'Java_Developer,Web_Developer,Software_Developer,Python_Developer'
#  'Java_Developer,Software_Developer,Python_Developer,Web_Developer'
#  'Python_Developer,Software_Developer,Security_Analyst,Web_Developer'
#  'Python_Developer,Software_Developer,Web_Developer,Systems_Administrator,Network_Administrator'
#  'Python_Developer,Software_Developer,Security_Analyst,Systems_Administrator'
#  'Web_Developer,Python_Developer,Software_Developer,Front_End_Developer,Systems_Administrator'
#  'Python_Developer,Software_Developer,Web_Developer,Security_Analyst,Network_Administrator,Systems_Administrator'
#  'Web_Developer,Software_Developer,Project_manager,Python_Developer'
#  'Java_Developer,Python_Developer,Software_Developer,Database_Administrator'
#  'Web_Developer,Python_Developer,Software_Developer,Project_manager'
#  'Python_Developer,Software_Developer,Systems_Administrator,Web_Developer'
#  'Web_Developer,Software_Developer,Java_Developer,Python_Developer'
#  'Python_Developer,Software_Developer,Front_End_Developer,Project_manager,Systems_Administrator'
#  'Software_Developer,Python_Developer,Systems_Administrator,Network_Administrator'
#  'Systems_Administrator,Python_Developer,Software_Developer,Web_Developer'
#  'Project_manager,Web_Developer,Software_Developer,Python_Developer'
#  'Java_Developer,Software_Developer,Python_Developer,Systems_Administrator'
#  'Software_Developer,Front_End_Developer,Python_Developer,Web_Developer,Systems_Administrator'
#  'Software_Developer,Web_Developer,Python_Developer,Network_Administrator,Systems_Administrator'
#  'Software_Developer,Java_Developer,Python_Developer'
#  'Software_Developer,Front_End_Developer,Java_Developer,Python_Developer,Web_Developer,Systems_Administrator,Project_manager'
#  'Python_Developer,Software_Developer,Web_Developer,Project_manager'
#  'Software_Developer,Python_Developer,Project_manager'
#  'Python_Developer,Software_Developer,Security_Analyst,Network_Administrator,Project_manager'
#  'Software_Developer,Java_Developer,Web_Developer,Python_Developer'
#  'Systems_Administrator,Python_Developer,Software_Developer,Security_Analyst'
#  'Java_Developer,Web_Developer,Python_Developer,Software_Developer'
#  'Software_Developer,Database_Administrator,Python_Developer'
#  'Python_Developer,Software_Developer,Web_Developer,Database_Administrator,Systems_Administrator'
#  'Software_Developer,Python_Developer,Web_Developer,Project_manager'
#  'Systems_Administrator,Python_Developer,Software_Developer,Database_Administrator'
#  'Web_Developer,Python_Developer,Software_Developer,Systems_Administrator,Project_manager'
#  'Database_Administrator,Python_Developer,Software_Developer,Project_manager'
#  'Web_Developer,Software_Developer,Front_End_Developer,Java_Developer,Python_Developer'
#  'Python_Developer,Software_Developer,Project_manager,Systems_Administrator'
#  'Software_Developer,Project_manager,Python_Developer,Web_Developer'
#  'Software_Developer,Web_Developer,Python_Developer,Front_End_Developer'
#  'Software_Developer,Python_Developer,Systems_Administrator,Database_Administrator'
#  'Python_Developer,Software_Developer,Database_Administrator,Project_manager'
#  'Python_Developer,Software_Developer,Project_manager,Web_Developer'
#  'Systems_Administrator,Python_Developer,Software_Developer'
#  'Database_Administrator,Web_Developer,Python_Developer,Software_Developer,Systems_Administrator'
#  'Python_Developer,Software_Developer,Security_Analyst,Database_Administrator,Project_manager,Web_Developer,Network_Administrator'
#  'Software_Developer,Systems_Administrator,Python_Developer,Web_Developer'
#  'Software_Developer,Python_Developer,Database_Administrator'
#  'Database_Administrator,Java_Developer,Software_Developer,Project_manager,Web_Developer,Python_Developer'
#  'Java_Developer,Software_Developer,Python_Developer,Project_manager'
#  'Python_Developer,Software_Developer,Database_Administrator,Security_Analyst,Project_manager,Web_Developer,Network_Administrator'
#  'Java_Developer,Software_Developer,Python_Developer,Web_Developer,Database_Administrator,Systems_Administrator'
#  'Python_Developer,Software_Developer,Front_End_Developer,Java_Developer,Web_Developer'
#  'Network_Administrator,Web_Developer,Python_Developer,Software_Developer'
#  'Python_Developer,Software_Developer,Web_Developer,Security_Analyst,Network_Administrator'
#  'Java_Developer,Software_Developer,Web_Developer,Python_Developer,Database_Administrator'
#  'Java_Developer,Python_Developer,Software_Developer,Network_Administrator,Web_Developer'
#  'Software_Developer,Python_Developer,Front_End_Developer'
#  'Web_Developer,Software_Developer,Database_Administrator,Python_Developer'
#  'Python_Developer,Software_Developer,Web_Developer,Network_Administrator'
#  'Project_manager,Web_Developer,Python_Developer,Software_Developer'
#  'Java_Developer,Python_Developer,Software_Developer,Security_Analyst'
#  'Java_Developer,Python_Developer,Software_Developer,Systems_Administrator'
#  'Database_Administrator,Software_Developer,Web_Developer,Python_Developer'
#  'Software_Developer,Project_manager,Python_Developer'
#  'Security_Analyst,Python_Developer,Software_Developer,Network_Administrator'
#  'Python_Developer,Software_Developer,Front_End_Developer,Web_Developer,Project_manager'
#  'Software_Developer,Web_Developer,Python_Developer,Java_Developer'
#  'Software_Developer,Java_Developer,Project_manager,Python_Developer'
#  'Python_Developer,Software_Developer,Web_Developer,Systems_Administrator'
#  'Software_Developer,Web_Developer,Systems_Administrator'
#  'Software_Developer,Web_Developer,Systems_Administrator,Project_manager'
#  'Systems_Administrator,Java_Developer,Web_Developer,Software_Developer'
#  'Software_Developer,Java_Developer,Web_Developer,Systems_Administrator'
#  'Software_Developer,Web_Developer,Network_Administrator'
#  'Software_Developer,Database_Administrator,Java_Developer,Python_Developer,Front_End_Developer'
#  'Software_Developer,Front_End_Developer,Web_Developer,Database_Administrator'
#  'Software_Developer,Systems_Administrator,Database_Administrator'
#  'Software_Developer,Front_End_Developer,Systems_Administrator,Web_Developer'
#  'Software_Developer,Database_Administrator,Network_Administrator,Web_Developer'
#  'Software_Developer,Project_manager,Network_Administrator,Database_Administrator'
#  'Network_Administrator,Software_Developer,Web_Developer'
#  'Software_Developer,Database_Administrator,Web_Developer,Java_Developer'
#  'Web_Developer,Software_Developer,Security_Analyst'
#  'Database_Administrator,Software_Developer,Web_Developer,Project_manager'
#  'Software_Developer,Front_End_Developer,Java_Developer,Web_Developer,Python_Developer'
#  'Systems_Administrator,Web_Developer,Software_Developer'
#  'Systems_Administrator,Network_Administrator,Database_Administrator,Web_Developer,Software_Developer'
#  'Systems_Administrator,Project_manager,Software_Developer'
#  'Systems_Administrator,Project_manager,Network_Administrator,Database_Administrator'
#  'Systems_Administrator,Project_manager,Software_Developer,Front_End_Developer'
#  'Systems_Administrator,Web_Developer,Software_Developer,Project_manager,Java_Developer,Database_Administrator'
#  'Systems_Administrator,Software_Developer,Network_Administrator'
#  'Systems_Administrator,Java_Developer,Web_Developer,Software_Developer,Network_Administrator'
#  'Systems_Administrator,Project_manager,Software_Developer,Network_Administrator'
#  'Web_Developer,Software_Developer,Security_Analyst,Systems_Administrator'
#  'Systems_Administrator,Software_Developer,Web_Developer'
#  'Software_Developer,Systems_Administrator,Network_Administrator,Web_Developer'
#  'Systems_Administrator,Project_manager,Database_Administrator,Network_Administrator'
#  'Security_Analyst,Systems_Administrator,Web_Developer,Software_Developer'
#  'Network_Administrator,Systems_Administrator,Web_Developer,Software_Developer'
#  'Systems_Administrator,Network_Administrator,Project_manager,Software_Developer'
#  'Project_manager,Web_Developer,Software_Developer,Network_Administrator'
#  'Web_Developer,Software_Developer,Systems_Administrator,Network_Administrator'
#  'Web_Developer,Software_Developer,Project_manager,Systems_Administrator'
#  'Project_manager,Web_Developer,Software_Developer,Database_Administrator'
#  'Web_Developer,Software_Developer,Network_Administrator,Systems_Administrator'
#  'Software_Developer,Network_Administrator,Web_Developer'
#  'Database_Administrator,Software_Developer,Project_manager,Web_Developer'
#  'Project_manager,Software_Developer,Web_Developer,Network_Administrator'
#  'Project_manager,Software_Developer,Systems_Administrator,Web_Developer,Database_Administrator'
#  'Software_Developer,Systems_Administrator,Web_Developer,Project_manager'
#  'Web_Developer,Software_Developer,Project_manager,Network_Administrator'
#  'Software_Developer,Web_Developer,Systems_Administrator,Network_Administrator'
#  'Software_Developer,Systems_Administrator,Web_Developer,Database_Administrator'
#  'Database_Administrator,Software_Developer,Front_End_Developer,Web_Developer']

# %% [markdown]
# - Exploring Categories - getting value counts of each category.

# %%
df1['Category'].value_counts()
# Out:
# Systems_Administrator                                                                            2349
# Project_manager                                                                                  2339
# Database_Administrator                                                                           2225
# Software_Developer                                                                               1991
# Web_Developer,Software_Developer                                                                 1896
#                                                                                                  ...
# Systems_Administrator,Security_Analyst,Project_manager,Web_Developer,Software_Developer             1
# Security_Analyst,Network_Administrator,Software_Developer,Systems_Administrator                     1
# Network_Administrator,Web_Developer,Software_Developer,Systems_Administrator,Security_Analyst       1
# Security_Analyst,Systems_Administrator,Project_manager,Software_Developer                           1
# Database_Administrator,Software_Developer,Front_End_Developer,Web_Developer                         1
# Name: Category, Length: 551, dtype: int64

# %%
temp_df = df1

# %% [markdown]
# # <b>Data Processing</b>

# %%
# Preprocessing libraries
import re
from sklearn.preprocessing import LabelEncoder
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer 
import string
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Cleaning Data:
# 1 Removing (URLs, hashtags, mentions, special letters, punctuations)
#
# 2 Tokenizing the cleaned text
#
# 3 Removing Stop Words
#
# 4 Performing Lemmatization on final text
#
# - The resumeKeywords function removes URLs, hashtags, mentions, special characters, non-ASCII characters, multiple spaces, and stop words from the input text while also performing tokenization, lowercasing, and lemmatization to provide cleaned and processed text as output.
#
# - <b>Tokenization:</b> Tokenization is the process of breaking a text into individual words or tokens. In this step, the text is split into its constituent words, which makes it easier to analyze and process. For example, the sentence "I love coding" would be tokenized into three tokens: "I," "love," and "coding."
#
# - <b> StopWords: </b> Stopwords are common words that are typically removed from text during natural language processing to improve text analysis and reduce noise in the data.Examples of common stopwords in English include "the," "and," "in," "is," "of," "it," "to," and many others. Removing stopwords from text helps reduce the dimensionality of the data and focuses the analysis on more meaningful words
#
# - <b>Lemmatization:</b> Lemmatization is the process of reducing words to their base or root form. This step is essential for text analysis because it reduces different forms of a word to a common base form. For example, the words "running" and "ran" would both be lemmatized to "run." This simplifies the text and ensures that similar words are treated as the same, which is crucial for accurate analysis and modeling.

# %%
def resumeKeywords(txt):   # sourcery skip: avoid-builtin-shadow, list-comprehension
    cleanText = re.sub('http\S+\s', ' ', txt) # Removing URLs
    cleanText = re.sub('#\S+\s', ' ', cleanText) # Removing hashtags
    cleanText = re.sub('@\S+', '  ', cleanText)  # Removing mentions
    cleanText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', cleanText) # Removing punctuations
    cleanText = re.sub(r'[^\x00-\x7f]', ' ', cleanText) # Removing non-ASCII characters
    cleanText = re.sub('\s+', ' ', cleanText) # Replace multiple spaces with a single space
    cleanText = cleanText.strip() # Removing leading and trailing whitespaces
    
    #------------Tokenizing Cleaned Text--------------------------------------------------------
    # Tokenizing our cleaned text
    tokenizer = nltk.tokenize.RegexpTokenizer('\w+')
    tokens = tokenizer.tokenize(cleanText)
    # Now lower everything and storing it in new variable words
    words = []
    for word in tokens:
        words.append(word.lower())
    #--------------------------------------------------------------------------------------------

    #-------------Removing Stop Words------------------------------------------------------------
    stopwords = nltk.corpus.stopwords.words('english')
    words_new = []
    for word in words:
        if word not in stopwords:
            words_new.append(word)
    #--------------------------------------------------------------------------------------------
    #-----------Performing Lemmatization---------------------------------------------------------
    wn = WordNetLemmatizer() 
    lemm_text = [wn.lemmatize(word) for word in words_new]
    #--------------------------------------------------------------------------------------------
    #----------Converting List into String-------------------------------------------------------
    processed_text = ' '.join(lemm_text)
    
    return processed_text

# %% [markdown]
# - Testing the above custom function to remove certain details from Resume

# %%
resumeKeywords(" https://www.github.com Software Engineer with 2 years of experience in Data Structures and Algorithms Agile Scrum, SDLC, C++, Java MVC, JavaScript, Web Development, Python " +
               "Data Science, Machine Learning / AI, and Mainframe technologies Programming Languages: 	C/C++, Java, Python, SQL, JCL, Cobol, DB2" + 
               "Frameworks: %#####	Java Spring, Spring boot, React, Angular, NodeJs" +
               "Tools: 	GIT, Visual Studio Code, Sublime, Spyder, Jupyter Notebook, Bluezone, Netbeans, Jira, Confluence, Kanban, CI/CD (Jenkins, GitLab, Azure-Devops), AWS," + 
               "Data-Bricks Libraries: 	NumPy, Pandas, Matplotlib, nltk, Scikit learn, TensorFlow, Keras Other: 	Problem-Solving, Quick Learner, Time-Management")
# Out:
# 'software engineer 2 year experience data structure algorithm agile scrum sdlc c java mvc javascript web development python data science machine learning ai mainframe technology programming language c c java python sql jcl cobol db2frameworks java spring spring boot react angular nodejstools git visual studio code sublime spyder jupyter notebook bluezone netbeans jira confluence kanban ci cd jenkins gitlab azure devops aws data brick library numpy panda matplotlib nltk scikit learn tensorflow kera problem solving quick learner time management'

# %% [markdown]
# #### Applying above created Custom Function to process the data and creating new column "Processed_Resume"

# %%
df1['Processed_Resume'] = df1['Resume'].apply(lambda x: resumeKeywords(x))
df1.head()
# Out:
#                                               Resume                Category  \
# 0  Database Administrator Database Administrator ...  Database_Administrator
# 1  Database Administrator Database Administrator ...  Database_Administrator
# 2  Oracle Database Administrator Oracle Database ...  Database_Administrator
# 3  Amazon Redshift Administrator and ETL Develope...  Database_Administrator
# 4  Scrum Master Scrum Master Scrum Master Richmon...  Database_Administrator
#
#                                     Processed_Resume
# 0  database administrator database administrator ...
# 1  database administrator database administrator ...
# 2  oracle database administrator oracle database ...
# 3  amazon redshift administrator etl developer bu...
# 4  scrum master scrum master scrum master richmon...

# %% [markdown]
# #### Generating WordCloud from the cleaned text

# %%
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\harsh\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\harsh\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\harsh\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\harsh\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\harsh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import plotly.express as px
import plotly.graph_objects as go
# Join the cleaned text into a single string
text = ' '.join(df1['Processed_Resume'])

# Create a word cloud
wordcloud = WordCloud(background_color='white',
                      width=1000,
                      height=800,
                      max_words=500,
                      colormap='viridis'
                      ).generate(text)

# Convert word cloud to an image
wordcloud_image = wordcloud.to_image()

# Display the word cloud using Plotly as an image
fig = px.imshow(wordcloud_image)
fig.update_layout(
    title='Word Cloud of Cleaned Text',
    xaxis_showticklabels=False,
    yaxis_showticklabels=False,
    plot_bgcolor='white'
)
fig.show()

# %% [markdown]
# #### Encoding the Category column and plotting it

# %%
# Label encoding our Category
label = LabelEncoder()
df1['Encoded_Category'] = label.fit_transform(df1['Category'])
df1.head()
# Out:
#                                               Resume                Category  \
# 0  Database Administrator Database Administrator ...  Database_Administrator
# 1  Database Administrator Database Administrator ...  Database_Administrator
# 2  Oracle Database Administrator Oracle Database ...  Database_Administrator
# 3  Amazon Redshift Administrator and ETL Develope...  Database_Administrator
# 4  Scrum Master Scrum Master Scrum Master Richmon...  Database_Administrator
#
#                                     Processed_Resume  Encoded_Category
# 0  database administrator database administrator ...                 0
# 1  database administrator database administrator ...                 0
# 2  oracle database administrator oracle database ...                 0
# 3  amazon redshift administrator etl developer bu...                 0
# 4  scrum master scrum master scrum master richmon...                 0

# %%
df1['Category'].sample(15)
# Out:
# 422              Software_Developer,Database_Administrator
# 26930                     Web_Developer,Software_Developer
# 29679    Web_Developer,Software_Developer,Front_End_Dev...
# 1469                Database_Administrator,Project_manager
# 3309     Web_Developer,Software_Developer,Front_End_Dev...
# 29507                     Web_Developer,Software_Developer
# 15489                                Network_Administrator
# 11949                                     Security_Analyst
# 3651     Software_Developer,Front_End_Developer,Web_Dev...
# 22274                                   Software_Developer
# 11962                                     Security_Analyst
# 15714    Project_manager,Systems_Administrator,Network_...
# 9963                                      Security_Analyst
# 15106                                Network_Administrator
# 26411                                Systems_Administrator
# Name: Category, dtype: object

# %%
# Create the mapping
category_mapping = df1.groupby('Encoded_Category')['Category'].first().to_dict()

# Print the created mapping
print("Created Category Mapping:")
print(category_mapping)
# Out:
# Created Category Mapping:
# {0: 'Database_Administrator', 1: 'Database_Administrator,Java_Developer,Python_Developer,Software_Developer', 2: 'Database_Administrator,Java_Developer,Software_Developer', 3: 'Database_Administrator,Java_Developer,Software_Developer,Project_manager', 4: 'Database_Administrator,Java_Developer,Software_Developer,Project_manager,Web_Developer,Python_Developer', 5: 'Database_Administrator,Java_Developer,Software_Developer,Systems_Administrator,Web_Developer', 6: 'Database_Administrator,Java_Developer,Software_Developer,Web_Developer', 7: 'Database_Administrator,Java_Developer,Web_Developer,Software_Developer', 8: 'Database_Administrator,Network_Administrator', 9: 'Database_Administrator,Network_Administrator,Project_manager', 10: 'Database_Administrator,Network_Administrator,Software_Developer', 11: 'Database_Administrator,Network_Administrator,Software_Developer,Systems_Administrator,Security_Analyst', 12: 'Database_Administrator,Network_Administrator,Systems_Administrator', 13: 'Database_Administrator,Network_Administrator,Web_Developer,Software_Developer,Systems_Administrator', 14: 'Database_Administrator,Project_manager', 15: 'Database_Administrator,Project_manager,Network_Administrator', 16: 'Database_Administrator,Project_manager,Software_Developer', 17: 'Database_Administrator,Project_manager,Software_Developer,Front_End_Developer,Java_Developer', 18: 'Database_Administrator,Project_manager,Systems_Administrator', 19: 'Database_Administrator,Project_manager,Systems_Administrator,Network_Administrator', 20: 'Database_Administrator,Project_manager,Systems_Administrator,Software_Developer', 21: 'Database_Administrator,Project_manager,Web_Developer,Software_Developer', 22: 'Database_Administrator,Python_Developer,Software_Developer', 23: 'Database_Administrator,Python_Developer,Software_Developer,Project_manager', 24: 'Database_Administrator,Security_Analyst', 25: 'Database_Administrator,Security_Analyst,Systems_Administrator', 26: 'Database_Administrator,Software_Developer', 27: 'Database_Administrator,Software_Developer,Front_End_Developer', 28: 'Database_Administrator,Software_Developer,Front_End_Developer,Web_Developer', 29: 'Database_Administrator,Software_Developer,Network_Administrator', 30: 'Database_Administrator,Software_Developer,Project_manager', 31: 'Database_Administrator,Software_Developer,Project_manager,Web_Developer', 32: 'Database_Administrator,Software_Developer,Security_Analyst', 33: 'Database_Administrator,Software_Developer,Systems_Administrator', 34: 'Database_Administrator,Software_Developer,Systems_Administrator,Project_manager', 35: 'Database_Administrator,Software_Developer,Web_Developer', 36: 'Database_Administrator,Software_Developer,Web_Developer,Project_manager', 37: 'Database_Administrator,Software_Developer,Web_Developer,Python_Developer', 38: 'Database_Administrator,Systems_Administrator', 39: 'Database_Administrator,Systems_Administrator,Java_Developer,Software_Developer', 40: 'Database_Administrator,Systems_Administrator,Network_Administrator', 41: 'Database_Administrator,Systems_Administrator,Project_manager', 42: 'Database_Administrator,Systems_Administrator,Project_manager,Software_Developer', 43: 'Database_Administrator,Systems_Administrator,Security_Analyst', 44: 'Database_Administrator,Systems_Administrator,Security_Analyst,Network_Administrator', 45: 'Database_Administrator,Systems_Administrator,Software_Developer', 46: 'Database_Administrator,Systems_Administrator,Software_Developer,Project_manager', 47: 'Database_Administrator,Systems_Administrator,Web_Developer,Software_Developer,Network_Administrator', 48: 'Database_Administrator,Web_Developer,Python_Developer,Software_Developer,Systems_Administrator', 49: 'Database_Administrator,Web_Developer,Software_Developer', 50: 'Database_Administrator,Web_Developer,Software_Developer,Front_End_Developer,Systems_Administrator', 51: 'Database_Administrator,Web_Developer,Software_Developer,Java_Developer', 52: 'Database_Administrator,Web_Deve ...

# %% [markdown]
# ### <b>#Vectorization (using TfidfVectorizer)</b>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english',max_features=29033)

tfidf.fit(df1['Processed_Resume'])
requiredText  = tfidf.transform(df1['Processed_Resume'])
print(requiredText)
# Out:
#   (0, 28875)	0.008492481678927806
#   (0, 28566)	0.010959879477079213
#   (0, 28552)	0.042823865421950914
#   (0, 28406)	0.029121651665376534
#   (0, 27628)	0.04673440083594293
#   (0, 27624)	0.016610927102728663
#   (0, 27552)	0.02851590882204456
#   (0, 27479)	0.01371202010586949
#   (0, 27458)	0.07438488582750953
#   (0, 27425)	0.014855684625616134
#   (0, 27331)	0.031342657322105553
#   (0, 27330)	0.019808407797841168
#   (0, 27324)	0.03445715581602325
#   (0, 27298)	0.019571895985584887
#   (0, 27281)	0.022675644904771693
#   (0, 27194)	0.02463186992150839
#   (0, 27177)	0.03928771720975392
#   (0, 27148)	0.05812821891275683
#   (0, 27133)	0.025192591868946644
#   (0, 27127)	0.01079288431716829
#   (0, 27124)	0.011581061647108348
#   (0, 27042)	0.05796497556242737
#   (0, 26951)	0.009209959865093906
#   (0, 26556)	0.07290209869277707
#   (0, 26552)	0.029322079394940703
#   :	:
#   (29032, 2749)	0.028799858642959017
#   (29032, 2644)	0.07828316211918149
#   (29032, 2555)	0.03949935471169789
#   (29032, 2492)	0.07177863573455685
#   (29032, 2429)	0.08520729655499144
#   (29032, 2375)	0.0570812193393168
#   (29032, 2343)	0.023210085264694785
#   (29032, 2206)	0.029649740886956592
#   (29032, 2171)	0.02589040601999931
#   (29032, 1996)	0.03883936799221341
#   (29032, 1992)	0.03297157651027444
#   (29032, 1693)	0.050697344537393586
#   (29032, 1285)	0.03789356745623993
#   (29032, 1013)	0.04134643568958074
#   (29032, 973)	0.04670132879799083
#   (29032, 914)	0.06697829680324582
#   (29032, 494)	0.03252105763556611
#   (29032, 377)	0.03285371698826866
#   (29032, 319)	0.07604069571428171
#   (29032, 318)	0.032115834147882036
#   (29032, 314)	0.029491587810107408
#   (29032, 313)	0.030749964281608998
#   (29032, 312)	0.01631111033990034
#   (29032, 282)	0.030804667340417754
#   (29032, 23)	0.018456290260474403

# %% [markdown]
# # <b>#Model Creation</b>

# %% [markdown]
# ### <b>#Splitting into Train and Test using (Vectorized text & Encoded category)</b>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(requiredText, df1['Encoded_Category'], test_size=0.35, random_state=42)
print(X_train.shape)

print(X_test.shape)
# Out:
# (18871, 29033)
# (10162, 29033)

# %% [markdown]
# ### <b>#Training the baseline model and printing its Accuracy</b>
# - KNeighbors Classifier
# - Multinomial NB

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

mnb = MultinomialNB()
mnb.fit(X_train,y_train)
y_pred1 = mnb.predict(X_test)
print('Accuracy: ', accuracy_score(y_test,y_pred1)*100, ' % \n')
print(classification_report(y_test, y_pred1))
# Out:
# Accuracy:  42.20625861050974  %
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.69      0.72       785
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         2
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00         9
#            9       0.00      0.00      0.00         3
#           12       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         1
#           14       0.00      0.00      0.00        14
#           15       0.00      0.00      0.00         1
#           18       0.00      0.00      0.00         1
#           22       0.00      0.00      0.00         2
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00         5
#           26       0.00      0.00      0.00        39
#           27       0.00      0.00      0.00         2
#           29       0.00      0.00      0.00         1
#           33       0.00      0.00      0.00         5
#           35       0.00      0.00      0.00         1
#           37       0.00      0.00      0.00         1
#           38       0.00      0.00      0.00        52
#           40       0.00      0.00      0.00         6
#           41       0.00      0.00      0.00         4
#           43       0.00      0.00      0.00         1
#           45       0.00      0.00      0.00         3
#           49       0.00      0.00      0.00        13
#           51       0.00      0.00      0.00         1
#           53       0.00      0.00      0.00         1
#           54       0.00      0.00      0.00         1
#           57       0.00      0.00      0.00         4
#           58       0.00      0.00      0.00         1
#           63       0.00      0.00      0.00         1
#           64       0.42      0.79      0.55       475
#           65       0.00      0.00      0.00         1
#           66       0.00      0.00      0.00        18
#           67       0.00      0.00      0.00         2
#           69       0.00      0.00      0.00         8
#           71       0.00      0.00      0.00         1
#           72       0.00      0.00      0.00         8
#           73       0.00      0.00      0.00         1
#           74       0.00      0.00      0.00         1
#           77       0.00      0.00      0.00         1
#           78       0.00      0.00      0.00         9
#           79       0.00      0.00      0.00         1
#           81       0.00      0.00      0.00       157
#           82       0.00      0.00      0.00        12
#           83       0.00      0.00      0.00         1
#           84       0.00      0.00      0.00         1
#           85       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00       139
#           90       0.00      0.00      0.00        12
#           91       0.00      0.00      0.00         1
#           93       0.00      0.00      0.00         1
#           94       0.61      0.15      0.24       520
#           95       0.00      0.00      0.00         6
#           97       0.00      0.00      0.00         1
#           98       0.00      0.00      0.00         2
#           99       0.00      0.00      0.00         1
#          101       0.00      0.00      0.00         9
#          102       0.00      0.00      0.00         1
#          103       0.00      0.00      0.00         1
#          105       0.00      0.00      0.00         5
#          107       0.00      0.00      0.00         1
#          108       0.00      0.00      0.00        59
#          109       0.00      0.00      0.00         1
#          110       0.00      0.00      0.00         1
#          114       0.00      0.00      0.00        14
#          115       0.00      0.00      0.00         1
#          117       0.00      0.00      0.00         5
#          119       0.00      0.00      0.00         1
#          120       0.00      0.00      0.00         1
#          121       0.00      0.00      0.00         1
#          123       0.00      0.00      0.00       132
#          125       0.00      0.00      0.00         7
#          126       0.00      0.00      0.00         1
#          127       0.00      0.00      0.00         3
#          128       0.00      0.00      0.00         1
#          129       0.00      0.00      0.00         1
#          131       0.00      0.00      0.00         3
#          133       0.00      0.00      0.00         1
#          134       0.47      0.87      0.61       873
#          135       0.00      0.00      0.00        21
#          137       0.00      0.00      0.00         1
#          138       0.00      0.00      0.00         1
#          139       0.00      0.00      0.00         4
#          142       0.00      0.00      0.00         4
#          144       0.00      0.00      0.00         1
#          145       0.00      0.00      0.00         4
#          146       0.00      0.00      0.00         1
#          149       0.00      0.00      0.00        71
#          151       0.00      0.00      0.00         5
#          154       0.00      0.00      0.00         9
#          155       0.00      0.00      0.00         1
#          158       0.00      0.00      0.00         1
#          159       0.00      0.00      0.00        42
#          160       0.00      0.00      0.00         2
#          161       0.00      0.00      0.00         1
#          163       0.00      0.00      0.00         6
#          167       0.00      0.00      0.00         3
#          170       0.00      0.00      0.00         2
#          171       0.00      0.00      0.00         6
#          173       0.00      0.00      0.00         1
#          174       0.00      0.00      0.00        75
#          175       0.00      0.00      0.00         2
#          176       0.00      0.00      0.00         5
#          177       0.00      0.00      0.00         3
#          179       0.00      0.00      0.00         1
#          181       0.00      0.00      0.00         1
#          182       0.00      0.00      0.00         1
#          188       0.00      0.00      0.00        57
#          189       0.00      0.00      0.00         1
#          191       0.00      0.00      0.00        26
#          196       0.00      0.00      0.00         4
#          197       0.00      0.00      0.00         1
#          198       0.00      0.00      0.00        15
#          200       0.00      0.00      0.00         2
#          203       0.00      0.00      0.00         1
#          205       0.48      0.84      0.61       590
#          206       0.00      0.00      0.00         7
#          207       0.00      0.00      0.00         1
#          211       0.00      0.00      0.00        12
#          213       0.00      0.00      0.00         1
#          214       0.00      0.00      0.00         4
#          216       0.00      0.00      0.00        55
#          218       0.00      0.00      0.00         1
#          219       0.00      0.00      0.00         3
#          220       0.00      0.00      0.00         5
#          222       0.00      0.00      0.00         6
#          224       0.00      0.00      0.00         1
#          226       0.00      0.00      0.00         1
#          227       0.00      0.00      0.00         1
#          228       0.00      0.00      0.00         1
#          229       0.00      0.00      0.00        12
#          230       0.00      0.00      0.00         1
#          231       0.00      0.00      0.00         1
#          232       0.00      0.00      0.00        66
#          233       0.00      0.00      0.00         1
#          234       0.00      0.00      0.00         1
#          235       0.00      0.00      0.00         8
#          236       0.00      0.00      0.00         8
#          237       0.00      0.00      0.00         1
#          238       0.00      0.00      0.00         1
#          239       0.00      0.00      0.00         1
#          243       0.68      0.58      0.63       539
#          244       0.00      0.00      0.00        11
#          245       0.00      0.00      0.00         1
#          247       0.00      0.00      0.00         1
#          248       0.00      0.00      0.00         1
#          249       0.00      0.00      0.00        50
#          250       0.00      0.00      0.00         1
#          251       0.00      0.00      0.00         2
#          254       0.00      0.00      0.00         1
#          255       0.00      0.00      0.00         4
#          256       0.00      0.00      0.00        42
#          258       0.00      0.00      0.00         3
#          260       0.00      0.00      0.00         1
#          262       0.00      0.00      0.00         4
#          263       0.00      0.00      0.00         2
#          264       0.00      0.00      0.00         1
#          265       0.00      0.00      0.00         1
#          269       0.00      0.00      0.00        10
#          270       0.00      0.00      0.00         1
#          272       0.00      0.00      0.00         1
#          276       0.00      0.00      0.00         2
#          280       0.00      0.00      0.00        64
#          281       0.00      0.00      0.00        19
#          282       0.00      0.00      0.00         1
#          284       0.00      0.00      0.00         5
#          285       0.00      0.00      0.00         4
#          286       0.00      0.00      0.00         1
#          287       0.00      0.00      0.00         4
#          289       0.00      0.00      0.00         5
#          292       0.00      0.00      0.00         1
#          293       0.00      0.00      0.00         1
#          295       0.38      0.62      0.47       722
#          296       0.00      0.00      0.00        20
#          300       0.00      0.00      0.00         1
#          304       0.00      0.00      0.00         2
#          305       0.00      0.00      0.00         5
#          307       0.00      0.00      0.00         1
#          309       0.39      0.27      0.32       488
#          312       0.00      0.00      0.00        26
#          315       0.00      0.00      0.00        13
#          318       0.00      0.00      0.00         1
#          320       0.00      0.00      0.00         5
#          321       0.00      0.00      0.00         1
#          323       0.00      0.00      0.00         1
#          324       0.00      0.00      0.00         6
#          325       0.00      0.00      0.00         1
#          326       0.00      0.00      0.00         6
#          329       1.00      0.01      0.01       288
#          331       0.00      0.00      0.00         1
#          332       0.00      0.00      0.00        11
#          333       0.00      0.00      0.00         2
#          334       0.00      0.00      0.00         4
#          335       0.00      0.00      0.00         1
#          336       0.00      0.00      0.00        76
#          337       0.00      0.00      0.00         1
#          339       0.00      0.00      0.00         1
#          340       0.00      0.00      0.00         1
#          342       0.00      0.00      0.00         1
#          343       0.00      0.00      0.00         2
#          344       0.00      0.00      0.00         1
#          345       0.00      0.00      0.00        27
#          346       0.00      0.00      0.00         2
#          349       0.00      0.00      0.00         8
#          352       0.00      0.00      0.00         1
#          353       0.00      0.00      0.00        15
#          354       0.00      0.00      0.00         1
#          355       0.00      0.00      0.00         1
#          357       0.00      0.00      0.00         2
#          359       0.00      0.00      0.00         1
#          360       0.00      0.00      0.00         1
#          361       0.00      0.00      0.00         1
#          362       0.00      0.00      0.00         1
#          363       0.00      0.00      0.00         1
#          364       0.00      0.00      0.00         1
#          365       0.00      0.00      0.00         2
#          367       0.00      0.00      0.00         4
#          368       0.00      0.00      0.00        42
#          369       0.00      0.00      0.00         1
#          372       0.00      0.00      0.00         1
#          374       0.00      0.00      0.00         2
#          379       0.00      0.00      0.00         5
#          380       0.00      0.00      0.00         1
#          381       0.00      0.00      0.00         3
#          384       0.00      0.00      0.00        20
#          385       0.00      0.00      0.00         1
#          387       0.00      0.00      0.00         3
#          388       0.00      0.00      0.00         1
#          390       0.00      0.00      0.00         1
#          394       0.00      0.00      0.00         1
#          395       0.00      0.00      0.00         1
#          396       0.00      0.00      0.00         2
#          397       0.00      0.00      0.00         5
#          399       0.00      0.00      0.00         1
#          400       0.00      0.00      0.00       168
#          401       0.00      0.00      0.00         4
#          404       0.00      0.00      0.00        33
#          407       0.00      0.00      0.00         1
#          408       0.00      0.00      0.00         3
#          409       0.00      0.00      0.00         4
#          410       0.00      0.00      0.00         2
#          411       0.00      0.00      0.00         1
#          412       0.00      0.00      0.00         1
#          413       0.00      0.00      0.00         9
#          416       0.00      0.00      0.00         1
#          419       0.00      0.00      0.00         1
#          421       0.00      0.00      0.00         3
#          424       0.28      0.90      0.43       813
#          425       0.00      0.00      0.00        36
#          426       0.00      0.00      0.00         3
#          427       0.00      0.00      0.00         1
#          429       0.00      0.00      0.00         1
#          432       0.00      0.00      0.00         3
#          435       0.00      0.00      0.00         1
#          437       0.00      0.00      0.00         1
#          438       0.00      0.00      0.00         1
#          439       0.00      0.00      0.00         1
#          440       0.00      0.00      0.00       398
#          441       0.00      0.00      0.00         2
#          443       0.00      0.00      0.00         1
#          444       0.00      0.00      0.00         1
#          445       0.00      0.00      0.00         5
#          448       0.00      0.00      0.00        19
#          450       0.00      0.00      0.00         2
#          451       0.00      0.00      0.00         5
#          452       0.00      0.00      0.00         1
#          453       0.00      0.00      0.00        48
#          456       0.00      0.00      0.00        28
#          458       0.00      0.00      0.00         1
#          459       0.00      0.00      0.00         1
#          460       0.00      0.00      0.00         1
#          461       0.00      0.00      0.00         1
#          462       0.00      0.00      0.00         1
#          463       0.00      0.00      0.00         1
#          466       0.00      0.00      0.00         1
#          467       0.00      0.00      0.00         3
#          471       0.00      0.00      0.00        51
#          473       0.00      0.00      0.00         4
#          475       0.00      0.00      0.00         2
#          476       0.00      0.00      0.00         1
#          478       0.00      0.00      0.00         1
#          479       0.00      0.00      0.00        18
#          481       0.00      0.00      0.00         3
#          483       0.00      0.00      0.00         1
#          485       0.00      0.00      0.00         1
#          486       0.00      0.00      0.00         1
#          487       0.00      0.00      0.00         2
#          488       0.00      0.00      0.00         1
#          489       0.00      0.00      0.00        10
#          490       0.00      0.00      0.00         1
#          491       0.00      0.00      0.00         2
#          492       0.00      0.00      0.00         1
#          494       0.00      0.00      0.00        42
#          496       0.00      0.00      0.00         1
#          499       0.00      0.00      0.00         4
#          501       0.00      0.00      0.00         1
#          502       0.00      0.00      0.00         1
#          503       0.00      0.00      0.00         2
#          505       0.33      0.63      0.44       666
#          506       0.00      0.00      0.00         9
#          507       0.00      0.00      0.00         1
#          508       0.00      0.00      0.00         1
#          509       0.00      0.00      0.00       336
#          510       0.00      0.00      0.00         1
#          512       0.00      0.00      0.00         9
#          515       0.00      0.00      0.00         1
#          517       0.00      0.00      0.00        12
#          519       0.00      0.00      0.00         2
#          520       0.00      0.00      0.00         4
#          522       0.00      0.00      0.00        11
#          523       0.00      0.00      0.00         1
#          524       0.00      0.00      0.00         1
#          526       0.00      0.00      0.00        10
#          528       0.00      0.00      0.00        19
#          529       0.00      0.00      0.00         3
#          530       0.00      0.00      0.00         1
#          534       0.00      0.00      0.00         1
#          535       0.00      0.00      0.00        12
#          536       0.00      0.00      0.00         1
#          537       0.00      0.00      0.00         1
#          538       0.00      0.00      0.00         2
#          539       0.00      0.00      0.00         1
#          541       0.00      0.00      0.00         1
#          542       0.00      0.00      0.00         2
#          544       0.00      0.00      0.00        13
#          545       0.00      0.00      0.00         2
#          546       0.00      0.00      0.00         1
#
#     accuracy                           0.42     10162
#    macro avg       0.02      0.02      0.02     10162
# weighted avg       0.33      0.42      0.33     10162
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
 knc = OneVsRestClassifier(KNeighborsClassifier())
 knc.fit(X_train,y_train)
 y_pred2 = knc.predict(X_test)
 print('Accuracy: ', accuracy_score(y_test,y_pred2)*100, ' %')
 print(classification_report(y_test, y_pred2))
# Out:
# Accuracy:  10.400881664141066  %
#               precision    recall  f1-score   support
#
#            0       0.25      0.03      0.05       551
#            6       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00         5
#            9       0.00      0.00      0.00         3
#           13       0.00      0.00      0.00         1
#           14       0.00      0.00      0.
0.00      0.00      0.00         0
#          528       0.00      0.00      0.00        15
#          529       0.00      0.00      0.00         0
#          530       0.00      0.00      0.00         1
#          533       0.00      0.00      0.00         0
#          535       0.00      0.00      0.00         7
#          536       0.00      0.00      0.00         1
#          537       1.00      1.00      1.00         1
#          538       0.00      0.00      0.00         1
#          539       1.00      1.00      1.00         1
#          540       0.00      0.00      0.00         0
#          541       0.00      0.00      0.00         1
#          542       0.50      1.00      0.67         1
#          544       0.00      0.00      0.00         7
#          545       0.00      0.00      0.00         2
#          546       0.00      0.00      0.00         1
#          547       0.00      0.00      0.00         0
#
#     accuracy                           0.10      7259
#    macro avg       0.05      0.04      0.04      7259
# weighted avg       0.14      0.10      0.10      7259
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning:
#
# Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# ### <b>#Training the advanced model and printing its Accuracy</b>
# - RNN

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the maximum number of words to consider
max_words = 100

# Tokenize and pad sequences
tokenizer = Tokenizer(num_words=max_words, split=' ')
tokenizer.fit_on_texts(df1['Processed_Resume'])
X = tokenizer.texts_to_sequences(df1['Processed_Resume'])
X = pad_sequences(X, maxlen=100)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, df1['Encoded_Category'], test_size=0.25, random_state=42)

# Build the RNN model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128, input_length=100))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100))
model.add(Dense(32, activation='relu'))
model.add(Dense(len(label.classes_), activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64)

# Evaluate the RNN model
# y_pred3 = model.predict(X_test)
y_pred_rnn_prob = model.predict(X_test)
y_pred3 = y_pred_rnn_prob.argmax(axis=-1)
accuracy_rnn = accuracy_score(y_test, y_pred3)
print('RNN Model Accuracy: {:.2f}%'.format(accuracy_rnn * 100))
print(classification_report(y_test, y_pred3))
# Accuracy is approx 61%
# Out:
# Epoch 1/150
# 341/341 [==============================] - 400s 1s/step - loss: 3.8633 - accuracy: 0.1008 - val_loss: 3.2556 - val_accuracy: 0.1529
# Epoch 2/150
# 341/341 [==============================] - 381s 1s/step - loss: 3.0705 - accuracy: 0.1910 - val_loss: 2.9233 - val_accuracy: 0.2290
# Epoch 3/150
# 341/341 [==============================] - 351s 1s/step - loss: 2.8028 - accuracy: 0.2579 - val_loss: 2.7029 - val_accuracy: 0.2966
# Epoch 4/150
# 341/341 [==============================] - 323s 948ms/step - loss: 2.5587 - accuracy: 0.3410 - val_loss: 2.4307 - val_accuracy: 0.3930
# Epoch 5/150
# 341/341 [==============================] - 316s 927ms/step - loss: 2.3232 - accuracy: 0.4171 - val_loss: 2.2640 - val_accuracy: 0.4441
# Epoch 6/150
# 341/341 [==============================] - 366s 1s/step - loss: 2.1534 - accuracy: 0.4715 - val_loss: 2.1083 - val_accuracy: 0.4941
# Epoch 7/150
# 341/341 [==============================] - 370s 1s/step - loss: 2.0199 - accuracy: 0.5100 - val_loss: 2.0090 - val_accuracy: 0.5258
# Epoch 8/150
# 341/341 [==============================] - 369s 1s/step - loss: 1.9204 - accuracy: 0.5299 - val_loss: 1.9367 - val_accuracy: 0.5385
# Epoch 9/150
# 341/341 [==============================] - 333s 975ms/step - loss: 1.8465 - accuracy: 0.5440 - val_loss: 1.9023 - val_accuracy: 0.5440
# Epoch 10/150
# 341/341 [==============================] - 344s 1s/step - loss: 1.7864 - accuracy: 0.5552 - val_loss: 1.8642 - val_accuracy: 0.5579
# Epoch 11/150
# 341/341 [==============================] - 339s 994ms/step - loss: 1.7308 - accuracy: 0.5622 - val_loss: 1.8332 - val_accuracy: 0.5599
# Epoch 12/150
# 341/341 [==============================] - 321s 942ms/step - loss: 1.6840 - accuracy: 0.5715 - val_loss: 1.7945 - val_accuracy: 0.5731
# Epoch 13/150
# 341/341 [==============================] - 317s 931ms/step - loss: 1.6396 - accuracy: 0.5799 - val_loss: 1.7793 - val_accuracy: 0.5738
# Epoch 14/150
# 341/341 [==============================] - 309s 907ms/step - loss: 1.5987 - accuracy: 0.5855 - val_loss: 1.7649 - val_accuracy: 0.5778
# Epoch 15/150
# 341/341 [==============================] - 310s 911ms/step - loss: 1.5571 - accuracy: 0.5934 - val_loss: 1.7429 - val_accuracy: 0.5807
# Epoch 16/150
# 341/341 [==============================] - 311s 912ms/step - loss: 1.5279 - accuracy: 0.5979 - val_loss: 1.7398 - val_accuracy: 0.5816
# Epoch 17/150
# 341/341 [==============================] - 311s 913ms/step - loss: 1.4933 - accuracy: 0.6042 - val_loss: 1.7269 - val_accuracy: 0.5891
# Epoch 18/150
# 341/341 [==============================] - 263s 771ms/step - loss: 1.4579 - accuracy: 0.6088 - val_loss: 1.7302 - val_accuracy: 0.5891
# Epoch 19/150
# 341/341 [==============================] - 202s 593ms/step - loss: 1.4318 - accuracy: 0.6165 - val_loss: 1.7085 - val_accuracy: 0.5933
# Epoch 20/150
# 341/341 [==============================] - 200s 587ms/step - loss: 1.3993 - accuracy: 0.6236 - val_loss: 1.7288 - val_accuracy: 0.5935
# Epoch 21/150
# 341/341 [==============================] - 199s 585ms/step - loss: 1.3734 - accuracy: 0.6277 - val_loss: 1.7302 - val_accuracy: 0.5946
# Epoch 22/150
# 341/341 [==============================] - 202s 593ms/step - loss: 1.3418 - accuracy: 0.6297 - val_loss: 1.7215 - val_accuracy: 0.5937
# Epoch 23/150
# 341/341 [==============================] - 193s 565ms/step - loss: 1.3189 - accuracy: 0.6385 - val_loss: 1.7192 - val_accuracy: 0.5972
# Epoch 24/150
# 341/341 [==============================] - 187s 548ms/step - loss: 1.2902 - accuracy: 0.6427 - val_loss: 1.7280 - val_accuracy: 0.5953
# Epoch 25/150
# 341/341 [==============================] - 183s 536ms/step - loss: 1.2653 - accuracy: 0.6472 - val_loss: 1.7461 - val_accuracy: 0.5948
# Epoch 26/150
# 341/341 [==============================] - 181s 531ms/step - loss: 1.2372 - accuracy: 0.6527 - val_loss: 1.7475 - val_accuracy: 0.5975
# Epoch 27/150
# 341/341 [==============================] - 199s 585ms/step - loss: 1.2142 - accuracy: 0.6551 - val_loss: 1.7688 - val_accuracy: 0.5979
# Epoch 28/150
# 341/341 [==============================] - 195s 570ms/step - loss: 1.1905 - accuracy: 0.6665 - val_loss: 1.7894 - val_accuracy: 0.6045
# Epoch 29/150
# 341/341 [==============================] - 196s 575ms/step - loss: 1.1606 - accuracy: 0.6707 - val_loss: 1.7802 - val_accuracy: 0.6037
# Epoch 30/150
# 341/341 [==============================] - 196s 576ms/step - loss: 1.1427 - accuracy: 0.6734 - val_loss: 1.8116 - val_accuracy: 0.5966
# Epoch 31/150
# 341/341 [==============================] - 184s 539ms/step - loss: 1.1180 - accuracy: 0.6798 - val_loss: 1.8181 - val_accuracy: 0.5999
# Epoch 32/150
# 341/341 [==============================] - 182s 535ms/step - loss: 1.0986 - accuracy: 0.6852 - val_loss: 1.8248 - val_accuracy: 0.6046
# Epoch 33/150
# 341/341 [==============================] - 181s 530ms/step - loss: 1.0742 - accuracy: 0.6903 - val_loss: 1.8530 - val_accuracy: 0.5994
# Epoch 34/150
# 341/341 [==============================] - 189s 554ms/step - loss: 1.0534 - accuracy: 0.6960 - val_loss: 1.8563 - val_accuracy: 0.6016
# Epoch 35/150
# 341/341 [==============================] - 184s 541ms/step - loss: 1.0347 - accuracy: 0.6966 - val_loss: 1.8673 - val_accuracy: 0.6016
# Epoch 36/150
# 341/341 [==============================] - 181s 530ms/step - loss: 1.0155 - accuracy: 0.7019 - val_loss: 1.9041 - val_accuracy: 0.5994
# Epoch 37/150
# 341/341 [==============================] - 197s 579ms/step - loss: 1.0024 - accuracy: 0.7080 - val_loss: 1.9002 - val_accuracy: 0.6037
# Epoch 38/150
# 341/341 [==============================] - 193s 565ms/step - loss: 0.9813 - accuracy: 0.7153 - val_loss: 1.9081 - val_accuracy: 0.6039
# Epoch 39/150
# 341/341 [==============================] - 192s 562ms/step - loss: 0.9629 - accuracy: 0.7157 - val_loss: 1.9346 - val_accuracy: 0.6026
# Epoch 40/150
# 341/341 [==============================] - 192s 563ms/step - loss: 0.9434 - accuracy: 0.7231 - val_loss: 1.9569 - val_accuracy: 0.5954
# Epoch 41/150
# 341/341 [==============================] - 345s 1s/step - loss: 0.9305 - accuracy: 0.7238 - val_loss: 1.9770 - val_accuracy: 0.6008
# Epoch 42/150
# 341/341 [==============================] - 373s 1s/step - loss: 0.9085 - accuracy: 0.7319 - val_loss: 2.0056 - val_accuracy: 0.6009
# Epoch 43/150
# 341/341 [==============================] - 385s 1s/step - loss: 0.8986 - accuracy: 0.7308 - val_loss: 2.0114 - val_accuracy: 0.6056
# Epoch 44/150
# 341/341 [==============================] - 397s 1s/step - loss: 0.8776 - accuracy: 0.7374 - val_loss: 2.0307 - val_accuracy: 0.6005
# Epoch 45/150
# 341/341 [==============================] - 403s 1s/step - loss: 0.8623 - accuracy: 0.7415 - val_loss: 2.0376 - val_accuracy: 0.6033
# Epoch 46/150
# 341/341 [==============================] - 393s 1s/step - loss: 0.8464 - accuracy: 0.7466 - val_loss: 2.0679 - val_accuracy: 0.5975
# Epoch 47/150
# 341/341 [==============================] - 355s 1s/step - loss: 0.8303 - accuracy: 0.7469 - val_loss: 2.0936 - val_accuracy: 0.6023
# Epoch 48/150
# 341/341 [==============================] - 311s 912ms/step - loss: 0.8196 - accuracy: 0.7515 - val_loss: 2.1171 - val_accuracy: 0.6009
# Epoch 49/150
# 341/341 [==============================] - 309s 906ms/step - loss: 0.8067 - accuracy: 0.7565 - val_loss: 2.1067 - val_accuracy: 0.5987
# Epoch 50/150
# 341/341 [==============================] - 321s 943ms/step - loss: 0.7899 - accuracy: 0.7622 - val_loss: 2.1412 - val_accuracy: 0.6037
# Epoch 51/150
# 341/341 [==============================] - 325s 952ms/step - loss: 0.7842 - accuracy: 0.7628 - val_loss: 2.1495 - val_accuracy: 0.5959
# Epoch 52/150
# 341/341 [==============================] - 366s 1s/step - loss: 0.7649 - accuracy: 0.7687 - val_loss: 2.1703 - val_accuracy: 0.6005
# Epoch 53/150
# 341/341 [==============================] - 376s 1s/step - loss: 0.7546 - accuracy: 0.7712 - val_loss: 2.1869 - val_accuracy: 0.5950
# Epoch 54/150
# 341/341 [==============================] - 347s 1s/step - loss: 0.7483 - accuracy: 0.7725 - val_loss: 2.2076 - val_accuracy: 0.6021
# Epoch 55/150
# 341/341 [==============================] - 341s 1s/step - loss: 0.7290 - accuracy: 0.7767 - val_loss: 2.2320 - val_accuracy: 0.6037
# Epoch 56/150
# 341/341 [==============================] - 240s 704ms/step - loss: 0.7127 - accuracy: 0.7809 - val_loss: 2.2684 - val_accuracy: 0.5987
# Epoch 57/150
# 341/341 [==============================] - 197s 577ms/step - loss: 0.7089 - accuracy: 0.7805 - val_loss: 2.2364 - val_accuracy: 0.5966
# Epoch 58/150
# 341/341 [==============================] - 192s 564ms/step - loss: 0.7017 - accuracy: 0.7826 - val_loss: 2.2585 - val_accuracy: 0.5995
# Epoch 59/150
# 341/341 [==============================] - 185s 541ms/step - loss: 0.6811 - accuracy: 0.7912 - val_loss: 2.2977 - val_accuracy: 0.6019
# Epoch 60/150
# 341/341 [==============================] - 193s 565ms/step - loss: 0.6767 - accuracy: 0.7900 - val_loss: 2.3169 - val_accuracy: 0.6028
# Epoch 61/150
# 341/341 [==============================] - 191s 561ms/step - loss: 0.6688 - accuracy: 0.7923 - val_loss: 2.3283 - val_accuracy: 0.6009
# Epoch 62/150
# 341/341 [==============================] - 185s 542ms/step - loss: 0.6574 - accuracy: 0.7951 - val_loss: 2.3540 - val_accuracy: 0.6038
# Epoch 63/150
# 341/341 [==============================] - 191s 561ms/step - loss: 0.6513 - accuracy: 0.7959 - val_loss: 2.3662 - val_accuracy: 0.6042
# Epoch 64/150
# 341/341 [==============================] - 186s 546ms/step - loss: 0.6341 - accuracy: 0.8044 - val_loss: 2.4007 - val_accuracy: 0.6039
# Epoch 65/150
# 341/341 [==============================] - 188s 551ms/step - loss: 0.6355 - accuracy: 0.7989 - val_loss: 2.4396 - val_accuracy: 0.6044
# Epoch 66/150
# 341/341 [==============================] - 201s 590ms/step - loss: 0.6237 - accuracy: 0.8065 - val_loss: 2.4347 - val_accuracy: 0.6060
# Epoch 67/150
# 341/341 [==============================] - 196s 576ms/step - loss: 0.6167 - accuracy: 0.8054 - val_loss: 2.4366 - val_accuracy: 0.5984
# Epoch 68/150
# 341/341 [==============================] - 193s 567ms/step - loss: 0.6045 - accuracy: 0.8110 - val_loss: 2.4889 - val_accuracy: 0.6052
# Epoch 69/150
# 131/341 [==========>...................] - ETA: 2:08 - loss: 0.5829 - accuracy: 0.8144
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# c:\Users\harsh\Desktop\Harsh_Patel_001242838_final\Harsh_Patel_final.ipynb Cell 42 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/harsh/Desktop/Harsh_Patel_001242838_final/Harsh_Patel_final.ipynb#Y166sZmlsZQ%3D%3D?line=25'>26</a> model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#      <a href='vscode-notebook-cell:/c%3A/Users/harsh/Desktop/Harsh_Patel_001242838_final/Harsh_Patel_final.ipynb#Y166sZmlsZQ%3D%3D?line=27'>28</a> # Train the model
# ---> <a href='vscode-notebook-cell:/c%3A/Users/harsh/Desktop/Harsh_Patel_001242838_final/Harsh_Patel_final.ipynb#Y166sZmlsZQ%3D%3D?line=28'>29</a> history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64)
#      <a href='vscode-notebook-cell:/c%3A/Users/harsh/Desktop/Harsh_Patel_001242838_final/Harsh_Patel_final.ipynb#Y166sZmlsZQ%3D%3D?line=30'>31</a> # Evaluate the RNN model
#      <a href='vscode-notebook-cell:/c%3A/Users/harsh/Desktop/Harsh_Patel_001242838_final/Harsh_Patel_final.ipynb#Y166sZmlsZQ%3D%3D?line=31'>32</a> # y_pred3 = model.predict(X_test)
#      <a href='vscode-notebook-cell:/c%3A/Users/harsh/Desktop/Harsh_Patel_001242838_final/Harsh_Patel_final.ipynb#Y166sZmlsZQ%3D%3D?line=32'>33</a> y_pred_rnn_prob = model.predict(X_test)
#
# File c:\Users\harsh\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\harsh\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node gradients/transpose_grad/transpose defined at (most recent call last):
# <stack traces unavailable>
# OOM when allocating tensor with shape[64,100,128] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator cpu
# 	 [[{{node gradients/transpose_grad/transpose}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[PartitionedCall]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_442200]

# %% [markdown]
# # <b>Prediction & Recommendation System</b>

# %% [markdown]
# #### <b>Saving the created models</b>

# %%
import pickle
pickle.dump(tfidf,open('tfidf.pkl','wb'))
pickle.dump(mnb, open('mnb.pkl', 'wb'))
pickle.dump(tokenizer, open('rnn_tokenizer.pkl','wb'))
pickle.dump(model, open('rnn.pkl', 'wb'))

# %%
resume_1 = """I am a data scientist specializing in machine
learning, deep learning, and computer vision. With
a strong background in mathematics, statistics,
and programming, I am passionate about
uncovering hidden patterns and insights in data.
I have extensive experience in developing
predictive models, implementing deep learning
algorithms, and designing computer vision
systems. My technical skills include proficiency in
Python, Sklearn, TensorFlow, and PyTorch.
What sets me apart is my ability to effectively
communicate complex concepts to diverse
audiences. I excel in translating technical insights
into actionable recommendations that drive
informed decision-making.
If you're looking for a dedicated and versatile data
scientist to collaborate on impactful projects, I am
eager to contribute my expertise. Let's harness the
power of data together to unlock new possibilities
and shape a better future.
Contact & Sources
Email: 611noorsaeed@gmail.com
Phone: 03442826192
Github: https://github.com/611noorsaeed
Linkdin: https://www.linkedin.com/in/noor-saeed654a23263/
Blogs: https://medium.com/@611noorsaeed
Youtube: Artificial Intelligence
ABOUT ME
WORK EXPERIENCE
SKILLES
NOOR SAEED
LANGUAGES
English
Urdu
Hindi
I am a versatile data scientist with expertise in a wide
range of projects, including machine learning,
recommendation systems, deep learning, and computer
vision. Throughout my career, I have successfully
developed and deployed various machine learning models
to solve complex problems and drive data-driven
decision-making
Machine Learnine
Deep Learning
Computer Vision
Recommendation Systems
Data Visualization
Programming Languages (Python, SQL)
Data Preprocessing and Feature Engineering
Model Evaluation and Deployment
Statistical Analysis
Communication and Collaboration
"""

# %%
resume_1 = """
John A. Smith
(555) 555-5555
john.smith@example.com
1 Main Street, Seattle, WA 98133

Profile
A Senior Software Engineer with six years of professional experience, specializing in fullstack development, MySQL, Oracle, and Python. A proven track record of managing large scale software engineering projects to support cloud deployments and integrations.

Professional Experience
Senior Software Engineer, Microsoft, Los Angeles, CA
August 2019-Current

Manage a software engineering team of 15+ personnel to build innovative web applications using Agile-Waterfall methodologies, oversee all aspects of full-stack development, and identify opportunities to enhance the user experience
Identify creative solutions and workflow optimizations to improve deployment timelines and reduce project roadblocks during development lifecycles
Serve as the Microsoft Azure SME for the software engineering department and resolve escalated software issues from junior team members
Software Engineer, Uber, Los Angeles, CA
June 2017-August 2019

Coordinated with a team of 30+ software engineers to re-engineer the system into a PHP-based 3-tier application for a global rideshare company with 300M users
Supported projects to improve geo transit data application tools for drivers and users, which contributed to a 20% increase in user satisfaction
Certifications
MCPS: Microsoft Certified Professional
LPIC-3 Senior Level Linux Certification
Code Camp Trainer
Oracle Certified Professional – Java SE Programmer
Microsoft Certified Solutions Developer
Google Certified Professional Cloud Architect
Key Skills
Application Development
Java/Python/C++/Ruby/Perl/PHP/React/Angular
Full-stack developer
MySQL/Oracle/RedHat/AIX
Analysis and visualization of data structures
Education
Master of Business Administration, Information Systems
California State University, Long Beach, CA, September 2018 – July 2020

Bachelor of Computer Science, Software Engineering Major
University of California, Los Angeles, CA, August 2015 – July 2018, 4.0 GPA


"""

# %% [markdown]
# #### <b> Predicting Resume-1 by KNearestClassifier model</b>

# %%
"""
import pickle

# Load the trained KNearest classifier model
clf = pickle.load(open('knc.pkl', 'rb'))

# Clean the input resume
cleaned_resume = resumeKeywords(resume_1)

# Transform the cleaned resume using the trained TfidfVectorizer
input_features = tfidf.transform([cleaned_resume])

# Make the prediction using the loaded classifier
prediction_id = clf.predict(input_features)[0]

category_name = category_mapping.get(prediction_id, "Unknown")

print("Predicted Category:", category_name)
print(prediction_id)
"""
# Out:
# '\nimport pickle\n\n# Load the trained KNearest classifier model\nclf = pickle.load(open(\'knc.pkl\', \'rb\'))\n\n# Clean the input resume\ncleaned_resume = resumeKeywords(resume_1)\n\n# Transform the cleaned resume using the trained TfidfVectorizer\ninput_features = tfidf.transform([cleaned_resume])\n\n# Make the prediction using the loaded classifier\nprediction_id = clf.predict(input_features)[0]\n\ncategory_name = category_mapping.get(prediction_id, "Unknown")\n\nprint("Predicted Category:", category_name)\nprint(prediction_id)\n'

# %% [markdown]
# #### <b> Predicting Resume-1 by Multinomial Naive Bayes model</b>

# %%
import pickle

# Load the trained  Multinomial Naive Bayes model
mnb = pickle.load(open('mnb.pkl', 'rb'))

# Clean the input resume
cleaned_resume = resumeKeywords(resume_1)

# Transform the cleaned resume using the trained TfidfVectorizer
input_features = tfidf.transform([cleaned_resume])

# Make the prediction using the loaded classifier
prediction_id = mnb.predict(input_features)[0]

category_name = category_mapping.get(prediction_id, "Unknown")

print("Predicted Category:", category_name)
print(prediction_id)
# Out:
# Predicted Category: Python_Developer,Software_Developer
# 205

# %% [markdown]
# #### <b> Predicting Resume-1 by RNN model</b>

# %%
import pickle
rnn = pickle.load(open('rnn.pkl', 'rb'))
rnn_tokenizer = pickle.load(open('rnn_tokenizer.pkl', 'rb'))
# Define the maximum number of words to consider
max_words = 5000
cleaned_resume = resumeKeywords(resume_1)  # Clean the input resume

# Tokenize the cleaned input resume
input_sequence = rnn_tokenizer.texts_to_sequences([cleaned_resume])
# Padding the sequences
input_sequence = pad_sequences(input_sequence, maxlen=100)

# Make the prediction using the loaded RNN model
predicted_probabilities = rnn.predict(input_sequence)

prediction_id = predicted_probabilities.argmax(axis=-1)
# Map the category ID to the category name using category_mapping
category_name = category_mapping.get(prediction_id[0], "Unknown")

print("Predicted Category:", category_name)
print("Predicted Category ID:", prediction_id[0])
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Category: Python_Developer,Software_Developer
# Predicted Category ID: 205

# %%
job_description_1="""
About the job
Join a top employer and advance your career. Aplin has partnered with an Edmonton-based company to hire a Data Scientist. 

In this exciting role, you will serve as the catalyst for data-driven decision-making, guiding our client toward unparalleled success in lead conversion, customer loyalty, predictive innovation, and inventory optimization. 

Responsibilities:
Dive deep into datasets to unveil the untapped potential in enhancing lead conversion rates.
Develop cutting-edge algorithms that predict customer preferences.
Pioneer loyalty programs that exert a magnetic influence, guaranteeing a continuous stream of returning customers.
Optimize inventory with precision, ensuring the right products are available at the right time.
Qualifications:
Bachelor's degree in Computer Science, Statistics, Applied Math, or related fields; a Master's or PhD will give your credentials an extra boost.
Proficiency in SQL, Python, R, or any other data manipulation language.
Hands-on experience in machine learning, predictive analytics, and various statistical modeling techniques.
Exceptional attention to detail, capable of identifying outliers in datasets with precision.
A passion for storytelling through data, recognizing the importance of context in making impactful decisions.
Outstanding collaboration skills to navigate seamlessly within teams, ensuring smooth progress on your journey.

"""

# %%
job_description_1="""
My technical skills include proficiency in
Python, Sklearn, TensorFlow, and PyTorch.
What sets me apart is my ability to effectively
communicate complex concepts to diverse
audiences. I excel in translating technical insights
into actionable recommendations that drive
informed decision-making.

ABOUT ME
WORK EXPERIENCE
SKILLES
NOOR SAEED
LANGUAGES
English
Urdu
Hindi
I am a versatile data scientist with expertise in a wide
range of projects, including machine learning,
recommendation systems, deep learning, and computer
vision. Throughout my career, I have successfully
developed and deployed various machine learning models
to solve complex problems and drive data-driven
decision-making
Machine Learnine
Deep Learning
Computer Vision
Recommendation Systems
Data Visualization
Programming Languages (Python, SQL)
Data Preprocessing and Feature Engineering
Model Evaluation and Deployment
Statistical Analysis
Communication and Collaboration
"""

# %%
job_description_1 = """
LMI is seeking a Software Developer or computer science graduate with 7+ years of proven experience in computer vision who has the desire and skill set to design machine vision sensors. You will work in a multi-disciplinary, multi-platform, engineering team (software, electrical, mechanical/optical) that develops new sensor products and supporting infrastructure (manufacturing and test equipment). The ideal candidate will have a passion for leading-edge technology, extensive experience developing production-ready software, strong critical thinking and problem-solving skills, and can work well autonomously yet still communicate effectively with a close-knit group of about 10 engineers. Previous leadership or project management experience is an asset as there is an opportunity to lead a team in this role.

This Senior Software Developer will work in the R&D team and report to the Software Engineering Manager.

Design and develop 3D acquisition algorithms for our sensors to produce 3D data from images
Develop components of our calibration and acquisition pipeline
Characterize and validate prototype sensor performance and integrate final designs with customers
Investigate solutions for challenging acquisition problems. Investigate improvements to our algorithms to enhance the performance of our sensors
Design and develop manufacturing software tools required to build the sensors and control key component performance (e.g. software tasks for focusing and aligning cameras/lasers/projectors, quantifying and adjusting sensor sensitivity, etc.)
Lead technical investigations and produce reports and documentation for senior management
Demonstrate leadership and ownership. Drive projects to completion, participate in frequent peer design and code reviews, and use your expertise to oversee and mentor others in the team
Proactively contribute to and implement continuous improvement initiatives
What do you need to be successful?

Degree / Diploma in Computer Science, Electrical/Computer Engineering or equivalent
5+ years work experience in a disciplined software development environment producing deliverable code
Solid knowledge of C/C++ and C# programming using Microsoft Visual Studio
Expertise in 3D metrology or computer vision (object detection, image restoration, scene reconstruction, signal processing, etc., but excluding machine learning) is required
Experience independently planning and completing complex projects/deliverables in a reliable time frame
Proficient with commonly used scripting languages like Python
Excellent understanding of object-oriented programming
Excellent understanding of commonly used data structures and algorithms (lists, trees, sorting, binning, etc.)
Excellent understanding of math and statistics
Excellent written and verbal communication
Solid understanding of memory management, threading/synchronization, networking
Previous scrum master experience or experience overseeing a small team is an asset
Experience developing for a manufacturing automation environment is an asset
Salary Range: $106,000 - $132,500 - $151,000

Expected Salary: Our typical hiring range will be +/- 10% of the midpoint listed above. Factors influencing this decision include qualifications and market conditions for the role.
"""

# %% [markdown]
# # Keywords extraction from provided Job Description and Resume

# %%
from sklearn.metrics.pairwise import cosine_similarity
cleaned_resume = resumeKeywords(resume_1)
cleaned_job_description = resumeKeywords(job_description_1)
vectors_1  = tfidf.transform([cleaned_resume])
vectors_2 = tfidf.transform([cleaned_job_description])
similarity_score = cosine_similarity(vectors_1,vectors_2)
print("Similarity Score:", similarity_score)
# Out:
# Similarity Score: [[0.09759586]]

# %% [markdown]
# # <b>Bulding Job Category Recommendation System for this dataset</b>

# %% [markdown]
# - Shape of the vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_1 = TfidfVectorizer(stop_words='english',max_features=500)

tfidf_1.fit(df1['Processed_Resume'][0:5000])
requiredText  = tfidf_1.transform(df1['Processed_Resume'][0:5000])
print(requiredText)
# Out:
#   (0, 498)	0.010773127752308145
#   (0, 494)	0.014234209928247962
#   (0, 492)	0.055329790174256765
#   (0, 490)	0.0409807231433724
#   (0, 484)	0.03363044368209837
#   (0, 483)	0.017487792771952695
#   (0, 482)	0.022139673369651686
#   (0, 481)	0.04037912812370037
#   (0, 474)	0.0711276063454855
#   (0, 473)	0.03270432159567591
#   (0, 472)	0.01384249645508328
#   (0, 471)	0.015057734151000694
#   (0, 470)	0.06685324629538808
#   (0, 467)	0.011389784481159864
#   (0, 462)	0.06702730593407363
#   (0, 461)	0.03256345102558259
#   (0, 454)	0.012481706190787135
#   (0, 452)	0.02774544922477802
#   (0, 451)	0.027584743754645386
#   (0, 450)	0.0562538237067085
#   (0, 447)	0.011873663791710475
#   (0, 446)	0.05118585576836502
#   (0, 445)	0.030884587632048016
#   (0, 444)	0.031858121134203304
#   (0, 441)	0.04549040682945522
#   :	:
#   (4999, 131)	0.05448517586981033
#   (4999, 125)	0.17259855017737538
#   (4999, 123)	0.16948100154173215
#   (4999, 121)	0.054423954532528955
#   (4999, 116)	0.038714404389223356
#   (4999, 99)	0.04121682315203566
#   (4999, 95)	0.12511091269385735
#   (4999, 89)	0.1299294036832585
#   (4999, 86)	0.04469059637775404
#   (4999, 85)	0.05177587041610436
#   (4999, 72)	0.049510883743608444
#   (4999, 70)	0.03849634990051929
#   (4999, 60)	0.04043936661990509
#   (4999, 59)	0.07492969001556853
#   (4999, 54)	0.06800591118932608
#   (4999, 47)	0.14499806674787435
#  0.0884087  0.         0.         0.         0.         0.
#  0.         0.06094267 0.07953631 0.         0.         0.
#  0.01859349 0.00960092 0.         0.         0.07436128 0.08544755
#  0.01291672 0.         0.01483036 0.12200495 0.         0.0202934
#  0.         0.         0.04422157 0.         0.         0.
#  0.         0.         0.         0.         0.06092668 0.0751926
#  0.         0.         0.         0.         0.13014433 0.
#  0.         0.         0.         0.07819295 0.04002726 0.
#  0.         0.03797724 0.         0.02090852 0.0215134  0.01828749
#  0.         0.01455412 0.         0.         0.         0.
#  0.07442292 0.         0.01680546 0.04216531 0.         0.
#  0.         0.02116695 0.         0.         0.         0.01512448
#  0.01579916 0.         0.         0.         0.07104795 0.
#  0.         0.4128773  0.         0.         0.         0.
#  0.         0.         0.09734184 0.         0.         0.04291066
#  0.         0.         0.         0.03960623 0.         0.12006142
#  0.         0.         0.37937341 0.         0.02322723 0.02418502
#  0.         0.         0.01542999 0.         0.         0.
#  0.         0.07504166 0.         0.05342396 0.         0.
#  0.         0.04460864 0.         0.04549041 0.         0.
#  0.03185812 0.03088459 0.05118586 0.01187366 0.         0.
#  0.05625382 0.02758474 0.02774545 0.         0.01248171 0.
#  0.         0.         0.         0.         0.         0.03256345
#  0.06702731 0.         0.         0.         0.         0.01138978
#  0.         0.         0.06685325 0.01505773 0.0138425  0.03270432
#  0.07112761 0.         0.         0.         0.         0.
#  0.         0.04037913 0.02213967 0.01748779 0.03363044 0.
#  0.         0.         0.         0.         0.04098072 0.
#  0.05532979 0.         0.01423421 0.         0.         0.
#  0.01077313 0.        ]

# %%
vectors
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.01077313,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.03999819,
#         0.        ],
#        [0.        , 0.21841025, 0.        , ..., 0.        , 0.08235419,
#         0.        ],
#        ...,
#        [0.14427286, 0.        , 0.        , ..., 0.03851859, 0.11795584,
#         0.0899475 ],
#        [0.03637417, 0.        , 0.        , ..., 0.13595865, 0.02973911,
#         0.03401644],
#        [0.        , 0.        , 0.        , ..., 0.17342256, 0.02950409,
#         0.        ]])

# %% [markdown]
# - Gives the total number of frequent words in the corpus

# %%
len(tfidf_1.get_feature_names_out())
# Out:
# 500

# %% [markdown]
# - Gives the list of most frequent words to less frequent words in the corpus

# %%
print(tfidf_1.get_feature_names_out())
# Out:
# ['10' '10g' '11' '11g' '12c' '2000' '2003' '2005' '2006' '2007' '2008'
#  '2009' '2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018'
#  '2019' '9i' 'ability' 'access' 'account' 'active' 'activity' 'ad'
#  'additional' 'addm' 'administration' 'administrator' 'adobe' 'agent'
#  'agile' 'aix' 'ajax' 'alert' 'analysis' 'analyst' 'analytics' 'angular'
#  'angularjs' 'apache' 'api' 'app' 'application' 'applied' 'april'
#  'architect' 'architecture' 'area' 'asm' 'asp' 'assist' 'assistant'
#  'assisted' 'associate' 'august' 'authorized' 'automated' 'automation'
#  'availability' 'awr' 'aws' 'azure' 'bachelor' 'backup' 'bank' 'based'
#  'basic' 'best' 'bootstrap' 'browser' 'bug' 'build' 'building' 'built'
#  'business' 'ca' 'campaign' 'capacity' 'case' 'center' 'certification'
#  'change' 'check' 'class' 'client' 'cloning' 'closely' 'cloud' 'cluster'
#  'cm' 'code' 'coding' 'college' 'com' 'communication' 'company' 'complete'
#  'complex' 'compliance' 'component' 'computer' 'concept' 'configuration'
#  'configure' 'configured' 'configuring' 'consultant' 'content' 'contract'
#  'control' 'core' 'create' 'created' 'creating' 'creation' 'creative'
#  'critical' 'cross' 'cs' 'css3' 'current' 'custom' 'customer' 'cycle'
#  'daily' 'data' 'database' 'day' 'db' 'db2' 'dba' 'december' 'department'
#  'deployment' 'design' 'designed' 'designer' 'designing' 'develop'
#  'developed' 'developer' 'developing' 'development' 'device' 'different'
#  'digital' 'disaster' 'disk' 'document' 'documentation' 'dom' 'dynamic'
#  'eclipse' 'education' 'email' 'employee' 'employer' 'end' 'engineer'
#  'engineering' 'ensure' 'enterprise' 'environment' 'error' 'etl' 'event'
#  'excel' 'excellent' 'existing' 'experience' 'experienced' 'expert'
#  'expertise' 'explain' 'export' 'extensive' 'extensively' 'feature'
#  'february' 'file' 'financial' 'fl' 'flow' 'form' 'framework' 'function'
#  'functional' 'functionality' 'gate' 'git' 'golden' 'good' 'google'
#  'graphic' 'grid' 'group' 'guard' 'hand' 'hardware' 'health' 'help' 'high'
#  'highly' 'hp' 'html' 'html5' 'ibm' 'implement' 'implementation'
#  'implemented' 'implementing' 'import' 'improve' 'improvement' 'include'
#  'included' 'including' 'index' 'industry' 'information' 'infrastructure'
#  'installation' 'installed' 'instance' 'integration' 'integrity'
#  'interactive' 'interface' 'internal' 'involved' 'issue' 'january' 'java'
#  'javascript' 'jira' 'job' 'jquery' 'json' 'jsp' 'july' 'june' 'key'
#  'knowledge' 'language' 'large' 'layout' 'le' 'lead' 'level' 'library'
#  'license' 'life' 'like' 'link' 'linux' 'load' 'loader' 'log' 'logical'
#  'maintain' 'maintained' 'maintaining' 'maintenance' 'make' 'manage'
#  'managed' 'management' 'manager' 'managing' 'march' 'marketing' 'master'
#  'material' 'md' 'medium' 'meet' 'meeting' 'member' 'methodology'
#  'microsoft' 'migrated' 'migration' 'mobile' 'model' 'modeling' 'module'
#  'mongodb' 'monitor' 'monitored' 'monitoring' 'multi' 'multiple' 'mvc'
#  'mysql' 'need' 'needed' 'net' 'network' 'new' 'node' 'non' 'november'
#  'ny' 'object' 'october' 'oem' 'office' 'online' 'operating' 'operation'
#  'optimization' 'oracle' 'order' 'organization' 'oriented' 'package'
#  'page' 'patch' 'perform' 'performance' 'performed' 'performing'
#  'photoshop' 'php' 'physical' 'pl' 'plan' 'planning' 'platform' 'point'
#  'policy' 'practice' 'present' 'presentation' 'privilege' 'problem'
#  'procedure' 'process' 'processing' 'product' 'production' 'professional'
#  'proficient' 'program' 'programming' 'project' 'provide' 'provided'
#  'providing' 'pump' 'python' 'qa' 'quality' 'query' 'r2' 'rac' 'react'
#  'real' 'record' 'recovery' 'redux' 'related' 'release' 'remote'
#  'replication' 'report' 'reporting' 'request' 'required' 'requirement'
#  'research' 'resolve' 'resource' 'responsibility' 'responsible'
#  'responsive' 'rest' 'restful' 'result' 'review' 'rman' 'role' 'running'
#  'sale' 'san' 'sas' 'schedule' 'scheduling' 'schema' 'school' 'science'
#  'script' 'scripting' 'scrum' 'search' 'security' 'senior' 'september'
#  'server' 'service' 'set' 'setting' 'setup' 'sharepoint' 'shell'
#  'shipping' 'single' 'site' 'skill' 'social' 'software' 'solaris'
#  'solution' 'source' 'space' 'specialist' 'spring' 'sql' 'sr' 'ssis'
#  'ssrs' 'stack' 'staff' 'standard' 'standby' 'state' 'storage' 'store'
#  'stored' 'strategy' 'strong' 'structure' 'student' 'studio'
#  'successfully' 'suite' 'support' 'supported' 'supporting' 'table' 'task'
#  'team' 'technical' 'technology' 'template' 'test' 'testing' 'time' 'toad'
#  'tool' 'trace' 'track' 'tracking' 'training' 'trigger' 'troubleshoot'
#  'troubleshooting' 'tuning' 'tx' 'ui' 'understanding' 'unit' 'university'
#  'unix' 'update' 'upgrade' 'use' 'used' 'user' 'using' 'utility'
#  'utilized' 'utilizing' 'ux' 'va' 'validation' 'various' 'vendor'
#  'version' 'view' 'visual' 'warehouse' 'web' 'website' 'weekly' 'window'
#  'wordpress' 'work' 'worked' 'working' 'writing' 'wrote' 'xml' 'year'
#  'york']

# %% [markdown]
# - Looking for most frequent word at certain indexes

# %%
print(tfidf_1.get_feature_names_out()[40])
print(tfidf_1.get_feature_names_out()[20])
print(tfidf_1.get_feature_names_out()[11])
print(tfidf_1.get_feature_names_out()[22])
print(tfidf_1.get_feature_names_out()[33])
print(tfidf_1.get_feature_names_out()[44])
# Out:
# analyst
# 2018
# 2009
# 9i
# adobe
# apache

# %% [markdown]
# ### Similarity Score (Cosine similarity method)
# - For recommending the similar job category we need to identify the nearest vectors of a particular job category vector.
# - In order to find out the nearest vectors, we use similarity score and it has two methods (1- Euclidean distance method) & (2- Cosine similarity method)
# - Here, I will be using cosine similarity method rather than euclidean distance method because euclidean distance does not perform well on higher dimensions
# - The similarity is inverse of distance. [0-1]
# - If 1 then similarity is high and if 0 then similarity is low

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)
# This will create result with values as distance/similarity between each vectors
print(similarity)
# Out:
# [[1.         0.55356146 0.36181173 ... 0.12277021 0.16406078 0.16211031]
#  [0.55356146 1.         0.28550621 ... 0.14020167 0.17869191 0.20984865]
#  [0.36181173 0.28550621 1.         ... 0.09355866 0.12097149 0.06100921]
#  ...
#  [0.12277021 0.14020167 0.09355866 ... 1.         0.41071336 0.44344625]
#  [0.16406078 0.17869191 0.12097149 ... 0.41071336 1.         0.40473632]
#  [0.16211031 0.20984865 0.06100921 ... 0.44344625 0.40473632 1.        ]]

# %%
print(similarity.shape)
# It finds out distance of each job with every job, and that is the reason why the shape of the similarity shape is (5000,5000)
print(similarity[0])
# Gives similarity score of first job with every job, it can also be seen that the first value is 1 which indicates that the value is the
# similarity score of first job with itself.
print(similarity[1])
# Out:
# (5000, 5000)
# [1.         0.55356146 0.36181173 ... 0.12277021 0.16406078 0.16211031]

# %%
df2 = df1
df2 = df2[['Category','Resume','Processed_Resume','Encoded_Category']][0:5000]
df2.head()
# Out:
#                  Category                                             Resume  \
# 0  Database_Administrator  Database Administrator Database Administrator ...
# 1  Database_Administrator  Database Administrator Database Administrator ...
# 2  Database_Administrator  Oracle Database Administrator Oracle Database ...
# 3  Database_Administrator  Amazon Redshift Administrator and ETL Develope...
# 4  Database_Administrator  Scrum Master Scrum Master Scrum Master Richmon...
#
#                                     Processed_Resume  Encoded_Category
# 0  database administrator database administrator ...                 0
# 1  database administrator database administrator ...                 0
# 2  oracle database administrator oracle database ...                 0
# 3  amazon redshift administrator etl developer bu...                 0
# 4  scrum master scrum master scrum master richmon...                 0

# %%
df2['Encoded_Category'].value_counts()
# Out:
# 0      2212
# 309     815
# 509     509
# 329     330
# 38      149
#        ...
# 25        1
# 39        1
# 307       1
# 250       1
# 316       1
# Name: Encoded_Category, Length: 189, dtype: int64

# %% [markdown]
# ### Creating function which will recommend top 5 job categories based on the predicted job category
#
# 1) Initially, if the predicted job category id is given, I will need to find out the index of that job category in my dataset
# 2) Based on index value, I will be able to know the list of similarity scores of that particular job category with every job category
# 3) Using Enumerate function to align index and values together while sorting the similarity score in descending order to get top-5 job category

# %% [markdown]
# 1) Based on given predicted job category id getting the index of that job category in my dataset

# %%
print(df2[df2['Encoded_Category'] == 0].index[0])
print(df2[df2['Encoded_Category'] == 38].index[0])
print(df2[df2['Encoded_Category'] == 26].index[0])
# Out:
# 0
# 88
# 17

# %% [markdown]
# 2) Based on the fetched index getting the similarity score list of that job

# %% [markdown]
# 3) Now as I need the top 5 similar job categories I will need to sort the data in descending order to get top-5.
# - However, there is a problem if I am sorting, the index position is getting lost. So, to solve this problem I am using enumerate function (which prints index with value)
# - Applying lambda function in that to sort in descending order according to the similarity score and not based on the index value.

# %%
# 2.------------------------------- 
print(similarity[0])
print(similarity[38]) 
print(similarity[26]) 
# 3.------------------------------- 
print("-------------------------------------------------------------------------------------------------------------------------------------")
print(list(enumerate(similarity[0]))) 
print(list(enumerate(similarity[38]))) 
print(list(enumerate(similarity[26]))) 
print("-------------------------------------------------------------------------------------------------------------------------------------")
print(sorted(list(enumerate(similarity[0])),reverse = True, key=lambda x:x[1])) 
print(sorted(list(enumerate(similarity[38])),reverse = True, key=lambda x:x[1])) 
print(sorted(list(enumerate(similarity[26])),reverse = True, key=lambda x:x[1]))
# Out:
# [1.         0.55356146 0.36181173 ... 0.12277021 0.16406078 0.16211031]
# [0.48251885 0.32406671 0.66838276 ... 0.07239426 0.16359409 0.10166563]
# [0.60267236 0.46790577 0.6564012  ... 0.12149165 0.19345431 0.12962868]
# -------------------------------------------------------------------------------------------------------------------------------------
# [(0, 1.0000000000000002), (1, 0.5535614620715451), (2, 0.36181173095186436), (3, 0.506076792233686), (4, 0.35426820386290453), (5, 0.5000667537861863), (6, 0.5082744443926042), (7, 0.620850076480139), (8, 0.6459173171996209), (9, 0.5680283736695639), (10, 0.4982842588118908), (11, 0.5774084628484435), (12, 0.5283007289051933), (13, 0.5344640328239794), (14, 0.800997545862586), (15, 0.7941591457625234), (16, 0.760524580956016), (17, 0.811711448538113), (18, 0.4680224211204071), (19, 0.48186554931294634), (20, 0.
0.8112120939054339), (2389, 0.8111937121770707), (202, 0.8109148146738228), (2700, 0.8108928754416596), (2707, 0.8107177692131309), (20, 0.8106452021769158), (864, 0.8102711906977322), (2821, 0.8098095252783668), (227, 0.8094087844984296), (430, 0.8090802369939449), (2862, 0.8089312416951673), (973, 0.8086336629231291), (399, 0.8084937682745706), (2773, 0.8084838932252375), (2066, 0.8084672849875859), (270, 0.8080480308680642), (2286, 0.807947732307792), (1107, 0.8077827836330987), (2795, 0.807583262455099), (2780, 0.8074298279918052), (130, 0.8073276993174437), (2879, 0.8072842591152153), (71, 0.8071752258175768), (2565, 0.8069135208502185), (2735, 0.8067678183026469), (2895, 0.8065660919120875), (2654, 0.8064674486452704), (230, 0.8061986908159681), (6, 0.8061425266217979), (2878, 0.8058744248264047), (662, 0.8056931047018626), (2751, 0.8052272477482557), (888, 0.804747481176961), (1505, 0.8041910303793305), (2956, 0.8033117172943411), (1074, 0.8032036307691276), (2750, 0.8030845773295701), (478, 0.8028556512897533), (294, 0.8027767252294316), (2684, 0.802681535396142), (120, 0.8023090530770173), (2804, 0.8022833867313747), (2797, 0.8020197960174411), (5, 0.8018188668856691), (862, 0.8016831528208737), (212, 0.8013537025184028), (2706, 0.8010812917793311), (497, 0.8010025506487284), (2718, 0.8009477536687093), (23, 0.8005430268413176), (2703, 0.8004577727337061), (2385, 0.8003712173874211), (2697, 0.8003693344942691), (2713, 0.80034476512803), (273, 0.7999377158507739), (2380, 0.7996567403933463), (248, 0.7993442325974903), (102, 0.7977 ...

# %% [markdown]
# - Final Custom function

# %%
def recommend(category):
    #Based on given predicted job category id getting the index of that job category in my dataset 
    index = df2[df2['Encoded_Category'] == category].index[0] 

    #Based on the fetched index getting the similarity score list of that job
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1]) 
    # print(distances) # For testing purpose
    
    unique_set = set([])
    similarity_score = []
    
    for i in distances[0:100]: 
        if len(unique_set) < 5:
            job = df2.iloc[i[0]].Category
            score = "{:.2f}".format(i[1])
            if job not in unique_set and score != "1.00":
                unique_set.add(job)
                similarity_score.append(i[1])
                print(f"{job}, {score}") # Print each unique value and its corresponding similarity score
        else:
            break

# %%
print(category_mapping.get(0))
recommend(0)
# Out:
# Database_Administrator
# Database_Administrator, 0.91
# Database_Administrator,Project_manager, 0.86
# Database_Administrator,Systems_Administrator, 0.84
# Database_Administrator,Software_Developer, 0.81
# Database_Administrator,Web_Developer,Software_Developer, 0.80

# %%
print(category_mapping.get(38))
recommend(38)
# Out:
# Database_Administrator,Systems_Administrator
# Project_manager,Database_Administrator, 0.51
# Database_Administrator, 0.50
# Network_Administrator, 0.49
# Systems_Administrator, 0.48
# Software_Developer,Systems_Administrator,Project_manager,Java_Developer,Database_Administrator,Web_Developer, 0.48

# %%
print(category_mapping.get(250))
recommend(250)
# Out:
# Security_Analyst,Network_Administrator,Database_Administrator,Systems_Administrator
# Database_Administrator, 0.78
# Database_Administrator,Systems_Administrator, 0.73
# Database_Administrator,Project_manager, 0.73
# Database_Administrator,Software_Developer, 0.66
# Database_Administrator,Web_Developer,Software_Developer, 0.61
